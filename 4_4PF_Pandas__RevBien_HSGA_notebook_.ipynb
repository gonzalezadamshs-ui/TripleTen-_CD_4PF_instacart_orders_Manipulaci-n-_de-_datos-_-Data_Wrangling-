# %% [markdown]
# # ¡Hola Hilary! <a class="tocSkip"></a>
#
# Mi nombre es Oscar Flores y tengo el gusto de revisar tu proyecto. Si tienes algún comentario que quieras agregar en tus respuestas te puedes referir a mi como Oscar, no hay problema que me trates de tú.
#
# Si veo un error en la primera revisión solamente lo señalaré y dejaré que tú encuentres de qué se trata y cómo arreglarlo. Debo prepararte para que te desempeñes como especialista en Data, en un trabajo real, el responsable a cargo tuyo hará lo mismo. Si aún tienes dificultades para resolver esta tarea, te daré indicaciones más precisas en una siguiente iteración.
#
# Te dejaré mis comentarios más abajo - **por favor, no los muevas, modifiques o borres**
#
# Comenzaré mis comentarios con un resumen de los puntos que están bien, aquellos que debes corregir y aquellos que puedes mejorar. Luego deberás revisar todo el notebook para leer mis comentarios, los cuales estarán en rectángulos de color verde, amarillo o rojo como siguen:
#
# <div class='alert alert-block alert-success'>
# <b>Comentario de Reviewer</b> <a class='tocSkip'></a>
#
# Muy bien! Toda la respuesta fue lograda satisfactoriamente.
# </div>
#
# <div class='alert alert-block alert-warning'>
# <b>Comentario de Reviewer</b> <a class='tocSkip'></a>
#
# Existen detalles a mejorar. Existen recomendaciones.
# </div>
#
# <div class='alert alert-block alert-danger'>
#
# <b>Comentario de Reviewer</b> <a class='tocSkip'></a>
#
# Se necesitan correcciones en el bloque. El trabajo no puede ser aceptado con comentarios en rojo sin solucionar.
# </div>
#
# Cualquier comentario que quieras agregar entre iteraciones de revisión lo puedes hacer de la siguiente manera:
#
#
#
# <div class='alert alert-block alert-info'>
# <b>Respuesta estudiante.</b> <a class='tocSkip'></a>
# </div>
#
#
#
# Mucho éxito en el proyecto!

# %% [markdown]
# ## Resumen de la revisión v1 <a class="tocSkip"></a>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# Hola Hilary, ¿cómo va todo? Espero que estés teniendo una buena jornada.
#
# Buen trabajo completando todos los puntos del notebook. El proyecto en general está bien logrado, con una correcta implementación del código necesario. Hay algunos errores de compilación a corregir, en conjunto con errores específicos como algunos detalles en la parte de análisis de los nulos y otros en la segunda mitad del notebook. Te dejé anotaciones en rojo con observaciones puntuales para que puedas hacer esos ajustes.
#
# Ante cualquier duda, no dudes en dejar un comentario en azul. Con gusto lo atenderé en la próxima iteración.
#
# Saludos!
#
#
# </div>

# %% [markdown]
# ## Resumen de la revisión v2 <a class="tocSkip"></a>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor  v2 </b> <a class="tocSkip"></a>
#
# ¡Buen trabajo Hilary! Las últimas correcciones quedaron muy bien. Completaste todas las tareas del notebook de forma correcta, así que no tengo más observaciones que hacer. El proyecto está aprobado. Todo lo que aplicaste aquí será de gran valor en futuros análisis. ¡Mucho éxito en lo que viene!
#
# Saludos.
#
# </div>

# %% [markdown]
# ----

# %% [markdown]
# # ¡Llena ese carrito!

# %% [markdown]
# # Introducción
#
# Instacart es una plataforma de entregas de comestibles donde la clientela puede registrar un pedido y hacer que se lo entreguen, similar a Uber Eats y Door Dash.
# El conjunto de datos que te hemos proporcionado tiene modificaciones del original. Redujimos el tamaño del conjunto para que tus cálculos se hicieran más rápido e introdujimos valores ausentes y duplicados. Tuvimos cuidado de conservar las distribuciones de los datos originales cuando hicimos los cambios.
#
# Debes completar tres pasos. Para cada uno de ellos, escribe una breve introducción que refleje con claridad cómo pretendes resolver cada paso, y escribe párrafos explicatorios que justifiquen tus decisiones al tiempo que avanzas en tu solución.  También escribe una conclusión que resuma tus hallazgos y elecciones.

# %% [markdown]
# ## Diccionario de datos
#
# Hay cinco tablas en el conjunto de datos, y tendrás que usarlas todas para hacer el preprocesamiento de datos y el análisis exploratorio de datos. A continuación se muestra un diccionario de datos que enumera las columnas de cada tabla y describe los datos que contienen.
#
# - `instacart_orders.csv`: cada fila corresponde a un pedido en la aplicación Instacart.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'user_id'`: número de ID que identifica de manera única la cuenta de cada cliente.
#     - `'order_number'`: el número de veces que este cliente ha hecho un pedido.
#     - `'order_dow'`: día de la semana en que se hizo el pedido (0 si es domingo).
#     - `'order_hour_of_day'`: hora del día en que se hizo el pedido.
#     - `'days_since_prior_order'`: número de días transcurridos desde que este cliente hizo su pedido anterior.
# - `products.csv`: cada fila corresponde a un producto único que pueden comprar los clientes.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'product_name'`: nombre del producto.
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
# - `order_products.csv`: cada fila corresponde a un artículo pedido en un pedido.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'add_to_cart_order'`: el orden secuencial en el que se añadió cada artículo en el carrito.
#     - `'reordered'`: 0 si el cliente nunca ha pedido este producto antes, 1 si lo ha pedido.
# - `aisles.csv`
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'aisle'`: nombre del pasillo.
# - `departments.csv`
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
#     - `'department'`: nombre del departamento.

# %% [markdown]
# # Paso 1. Descripción de los datos
#
# Lee los archivos de datos (`/datasets/instacart_orders.csv`, `/datasets/products.csv`, `/datasets/aisles.csv`, `/datasets/departments.csv` y `/datasets/order_products.csv`) con `pd.read_csv()` usando los parámetros adecuados para leer los datos correctamente. Verifica la información para cada DataFrame creado.

# %% [markdown]
# ## Plan de solución
#
# Escribe aquí tu plan de solución para el Paso 1. Descripción de los datos.

# %%
# importar librerías

import pandas as pd

# %%
# leer conjuntos de datos en los DataFrames

# %% [markdown]
# # Comenzamos a trabajar con el DataFrame **instacart_orders**
# # observamos **poca legibilidad de los datos**

# %%
#leer conjuntos de datos en los DataFrames (instacart_orders.csv)
instacart_orders = pd.read_csv('data/instacart_orders (1).csv')

# %%
# mostrar informacion del data frame
# en el cual me doy cuenta de la poca legibilidad que muestra
instacart_orders.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 478967 entries, 0 to 478966
# Data columns (total 1 columns):
#  #   Column                                                                            Non-Null Count   Dtype
# ---  ------                                                                            --------------   -----
#  0   order_id;user_id;order_number;order_dow;order_hour_of_day;days_since_prior_order  478967 non-null  str
# dtypes: str(1)
# memory usage: 3.7 MB

# %%
#describir el data frame
#tambien podemos notar la poca legibilidad
#del DataFrame instacart_orders
instacart_orders.describe()
# Out:
#        order_id;user_id;order_number;order_dow;order_hour_of_day;days_since_prior_order
# count                                              478967
# unique                                             478952
# top                            1918001;188546;14;3;2;16.0
# freq                                                    2

# %%
#mostramos las primeras 5 filas del dataFrame instacart_orders
#vemos igualmente una poca legibilidadd de los datos
instacart_orders.head()
# Out:
#   order_id;user_id;order_number;order_dow;order_hour_of_day;days_since_prior_order
# 0                        1515936;183418;11;6;13;30.0
# 1                          1690866;163593;5;5;12;9.0
# 2                           1454967;39980;4;5;19;2.0
# 3                         1768857;82516;56;0;20;10.0
# 4                         3007858;196724;2;4;12;17.0

# %% [markdown]
# # **Aqui Trabajamos con el DataFrame instacart_orders_s**
# # y visualizamos **datos más ordenados**

# %%
#hacemos la lectura del archivo
#nombramos la variable instacart_order:sep
# Ahora que el archivo (instacart_orders_s) está correctamente leído
#con el separador ';', mediante la duncion sep=
#mostraremos su información imprimiendo la información
#mostramos las primeras filas.
#observamos una mejor lectura de los datos
instacart_orders_s = pd.read_csv('data/instacart_orders (1).csv', sep=";")
print(instacart_orders_s.head())
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   1515936   183418            11          6                 13
# 1   1690866   163593             5          5                 12
# 2   1454967    39980             4          5                 19
# 3   1768857    82516            56          0                 20
# 4   3007858   196724             2          4                 12
#
#    days_since_prior_order
# 0                    30.0
# 1                     9.0
# 2                     2.0
# 3                    10.0
# 4                    17.0

# %%
#mostramos la informacion del DataFrame (instacart_orders_sep)
#Observamos una mejor legibilidad de los datos
instacart_orders_s.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 478967 entries, 0 to 478966
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                478967 non-null  int64
#  1   user_id                 478967 non-null  int64
#  2   order_number            478967 non-null  int64
#  3   order_dow               478967 non-null  int64
#  4   order_hour_of_day       478967 non-null  int64
#  5   days_since_prior_order  450148 non-null  float64
# dtypes: float64(1), int64(5)
# memory usage: 21.9 MB

# %%
#mediante la función describe,
#describimos la informacion del DataFrame (instacart_orders_sep)
#Observamos una mejor legibilidad de los datos
instacart_orders_s.describe()
# Out:
#            order_id        user_id   order_number      order_dow  \
# count  4.789670e+05  478967.000000  478967.000000  478967.000000
# mean   1.709947e+06  102966.537475      17.157808       2.775058
# std    9.869480e+05   59525.328991      17.704688       2.045869
# min    4.000000e+00       2.000000       1.000000       0.000000
# 25%    8.564685e+05   51414.000000       5.000000       1.000000
# 50%    1.709522e+06  102633.000000      11.000000       3.000000
# 75%    2.562990e+06  154419.000000      23.000000       5.000000
# max    3.421079e+06  206209.000000     100.000000       6.000000
#
#        order_hour_of_day  days_since_prior_order
# count      478967.000000           450148.000000
# mean           13.446676               11.101751
# std             4.224986                9.189975
# min             0.000000                0.000000
# 25%            10.000000                4.000000
# 50%            13.000000                7.000000
# ...

# %%
#mediante la función describe,
#describimos la informacion del DataFrame (instacart_orders_sep)
#Observamos una mejor legibilidad de los datos
instacart_orders_s.describe()
# Out:
#            order_id        user_id   order_number      order_dow  \
# count  4.789670e+05  478967.000000  478967.000000  478967.000000
# mean   1.709947e+06  102966.537475      17.157808       2.775058
# std    9.869480e+05   59525.328991      17.704688       2.045869
# min    4.000000e+00       2.000000       1.000000       0.000000
# 25%    8.564685e+05   51414.000000       5.000000       1.000000
# 50%    1.709522e+06  102633.000000      11.000000       3.000000
# 75%    2.562990e+06  154419.000000      23.000000       5.000000
# max    3.421079e+06  206209.000000     100.000000       6.000000
#
#        order_hour_of_day  days_since_prior_order
# count      478967.000000           450148.000000
# mean           13.446676               11.101751
# std             4.224986                9.189975
# min             0.000000                0.000000
# 25%            10.000000                4.000000
# 50%            13.000000                7.000000
# ...

# %% [markdown]
# se trabajo instacart_order_s su legibilidad mediante sep=, visualizamos datos de las 5 primeras filas mediante el metodo head(), utilizamos la funcion info() y describe() para visualizar un panorama mas general de los datos e información.

# %% [markdown]
# # **Comenzamos a trabajar con DataFrame products**
# # observamos poca legibilidad de los datos

# %%
# leer conjuntos de datos en los DataFrames (products.csv)
products = pd.read_csv('data/products (1).csv')

# %%
# mostrar información del DataFrame
# observamos poca legibilidad
products.info()
products.describe()
products.head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 49694 entries, 0 to 49693
# Data columns (total 1 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   product_id;product_name;aisle_id;department_id  49694 non-null  str
# dtypes: str(1)
# memory usage: 388.4 KB
#       product_id;product_name;aisle_id;department_id
# 0                 1;Chocolate Sandwich Cookies;61;19
# 1                          2;All-Seasons Salt;104;13
# 2        3;Robust Golden Unsweetened Oolong Tea;94;7
# 3  4;Smart Ones Classic Favorites Mini Rigatoni W...
# 4                   5;Green Chile Anytime Sauce;5;13

# %% [markdown]
# # **Aqui Trabajamos con el DataFrame products_s,**
#
# # y visualizamos datos más ordenados

# %%
# hacemos la lectura del archivo
# nombramos la variable products_s
# Ahora que el archivo (products_s) está correctamente leído
# con el separador ';', mediante la duncion sep=
# mostraremos su información imprimiendo la información
# mostramos las primeras filas.
# observamos una mejor lectura de los datos
products_s = pd.read_csv('data/products (1).csv', sep=";")
print(products_s.head())
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13

# %%
#mostramos la informacion del DataFrame (products_s)
#Observamos una mejor legibilidad de los datos
products_s.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 49694 entries, 0 to 49693
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49694 non-null  int64
#  1   product_name   48436 non-null  str
#  2   aisle_id       49694 non-null  int64
#  3   department_id  49694 non-null  int64
# dtypes: int64(3), str(1)
# memory usage: 1.5 MB

# %%
# mediante la función describe,
# describimos la informacion del DataFrame (products_s)
# Observamos una mejor legibilidad de los datos
products_s.describe()
# Out:
#          product_id      aisle_id  department_id
# count  49694.000000  49694.000000   49694.000000
# mean   24847.500000     67.773192      11.728478
# std    14345.566475     38.317265       5.850314
# min        1.000000      1.000000       1.000000
# 25%    12424.250000     35.000000       7.000000
# 50%    24847.500000     69.000000      13.000000
# 75%    37270.750000    100.000000      17.000000
# max    49694.000000    134.000000      21.000000

# %% [markdown]
# se trabajo products_s su legibilidad mediante sep=, visualizamos datos de las 5 primeras filas mediante el metodo head(), utilizamos la funcion info() y describe() para visualizar un panorama mas general de los datos e información.

# %% [markdown]
# # **Comenzamos a trabajar con DataFrame order_products,**
#
# # observamos poca legibilidad de los datos

# %%
# leer conjuntos de datos en los DataFrames (order_products.csv)
order_products = pd.read_csv('data/order_products (1).csv')

# %%
# mostrar información del DataFrame
order_products.info()
order_products.describe()
order_products.head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 1 columns):
#  #   Column                                           Dtype
# ---  ------                                           -----
#  0   order_id;product_id;add_to_cart_order;reordered  str
# dtypes: str(1)
# memory usage: 34.7 MB
#   order_id;product_id;add_to_cart_order;reordered
# 0                            2141543;11440;17.0;0
# 1                               567889;1560;1.0;1
# 2                             2261212;26683;1.0;1
# 3                              491251;8670;35.0;1
# 4                              2571142;1940;5.0;1

# %% [markdown]
# # **Aqui Aqui Trabajamos con el DataFrame order_products_s,
# # y visualizamos datos más ordenados**

# %%
# hacemos la lectura del archivo
# nombramos la variable order_products_s
# Ahora que el archivo (order_products_s) está correctamente leído
# con el separador ';', mediante la duncion sep=
# mostraremos su información imprimiendo la información
# mostramos las primeras filas.
# observamos una mejor lectura de los datos
order_products_s = pd.read_csv('data/order_products (1).csv', sep=";")
print(order_products_s.head())
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0   2141543       11440               17.0          0
# 1    567889        1560                1.0          1
# 2   2261212       26683                1.0          1
# 3    491251        8670               35.0          1
# 4   2571142        1940                5.0          1

# %%
#mostramos la informacion del DataFrame (order_products_s)
#Observamos una mejor legibilidad de los datos
order_products_s.info(show_counts=True)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   order_id           4545007 non-null  int64
#  1   product_id         4545007 non-null  int64
#  2   add_to_cart_order  4544171 non-null  float64
#  3   reordered          4545007 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 138.7 MB

# %%
# mediante la función describe,
# describimos la informacion del DataFrame (order_products_s)
# Observamos una mejor legibilidad de los datos
order_products_s.describe()
# Out:
#            order_id    product_id  add_to_cart_order     reordered
# count  4.545007e+06  4.545007e+06       4.544171e+06  4.545007e+06
# mean   1.711166e+06  2.558084e+04       8.351669e+00  5.905025e-01
# std    9.850955e+05  1.409552e+04       7.080368e+00  4.917411e-01
# min    4.000000e+00  1.000000e+00       1.000000e+00  0.000000e+00
# 25%    8.608170e+05  1.353500e+04       3.000000e+00  0.000000e+00
# 50%    1.711530e+06  2.527200e+04       6.000000e+00  1.000000e+00
# 75%    2.561311e+06  3.793500e+04       1.100000e+01  1.000000e+00
# max    3.421079e+06  4.969400e+04       6.400000e+01  1.000000e+00

# %% [markdown]
# se trabajo order_products_s su legibilidad mediante sep=, visualizamos datos de las 5 primeras filas mediante el metodo head(), utilizamos la funcion info() y describe() para visualizar un panorama mas general de los datos e información.

# %% [markdown]
# # Comenzamos a trabajar con el DataFrame aisle
# # observamos poca legibilidad de los datos

# %%
# leer conjuntos de datos en los DataFrames (aisles.csv)
aisle = pd.read_csv('data/aisles (1).csv')

# %%
# mostrar información del DataFrame
aisle.info()
aisle.describe()
aisle.head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 1 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   aisle_id;aisle  134 non-null    str
# dtypes: str(1)
# memory usage: 1.2 KB
#                  aisle_id;aisle
# 0       1;prepared soups salads
# 1           2;specialty cheeses
# 2         3;energy granola bars
# 3               4;instant foods
# 4  5;marinades meat preparation

# %% [markdown]
# # **Aqui Trabajamos con el DataFrame **aisle_s**,
# ## y visualizamos datos más ordenados**

# %%
# hacemos la lectura del archivo
# nombramos la variable aisle_s
# Ahora que el archivo (aisle_s) está correctamente leído
# con el separador ';', mediante la duncion sep=
# mostraremos su información imprimiendo la información
# mostramos las primeras filas.
# observamos una mejor lectura de los datos
aisle_s = pd.read_csv('data/aisles (1).csv', sep=";")
print(aisle_s.head())
# Out:
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation

# %%
#mostramos la informacion del DataFrame (aisle_s)
#Observamos una mejor legibilidad de los datos
aisle_s.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   aisle_id  134 non-null    int64
#  1   aisle     134 non-null    str
# dtypes: int64(1), str(1)
# memory usage: 2.2 KB

# %%
# mediante la función describe,
# describimos la informacion del DataFrame (aisle_s)
# Observamos una mejor legibilidad de los datos
aisle_s.describe()
# Out:
#          aisle_id
# count  134.000000
# mean    67.500000
# std     38.826537
# min      1.000000
# 25%     34.250000
# 50%     67.500000
# 75%    100.750000
# max    134.000000

# %% [markdown]
# se trabajo aisle_s su legibilidad mediante sep=, visualizamos datos de las 5 primeras filas mediante el metodo head(), utilizamos la funcion info() y describe() para visualizar un panorama mas general de los datos e información.

# %% [markdown]
# # Comenzamos a trabajar con el DataFrame departaments
# # observamos poca legibilidad de los datos

# %%
# leer conjuntos de datos en los DataFrames (departments.csv)
departaments = pd.read_csv('data/departments (1).csv')

# %%
# mostrar información del DataFrame
departaments.info()
departaments.describe()
departaments.head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 1 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   department_id;department  21 non-null     str
# dtypes: str(1)
# memory usage: 300.0 bytes
#   department_id;department
# 0                 1;frozen
# 1                  2;other
# 2                 3;bakery
# 3                4;produce
# 4                5;alcohol

# %% [markdown]
# # **Aqui Trabajamos con el DataFrame departaments_s,
# # y visualizamos datos más ordenados**

# %%
# hacemos la lectura del archivo
# nombramos la variable departaments_s
# Ahora que el archivo (departaments_s) está correctamente leído
# con el separador ';', mediante la duncion sep=
# mostraremos su información imprimiendo la información
# mostramos las primeras filas.
# observamos una mejor lectura de los datos
departaments_s = pd.read_csv('data/departments (1).csv', sep=";")
print(departaments_s.head())
# Out:
#    department_id department
# 0              1     frozen
# 1              2      other
# 2              3     bakery
# 3              4    produce
# 4              5    alcohol

# %%
#mostramos la informacion del DataFrame (departaments_s)
#Observamos una mejor legibilidad de los datos
departaments_s.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   department_id  21 non-null     int64
#  1   department     21 non-null     str
# dtypes: int64(1), str(1)
# memory usage: 468.0 bytes

# %%
# mediante la función describe,
# describimos la informacion del DataFrame (departaments_s)
# Observamos una mejor legibilidad de los datos
departaments_s.describe()
# Out:
#        department_id
# count      21.000000
# mean       11.000000
# std         6.204837
# min         1.000000
# 25%         6.000000
# 50%        11.000000
# 75%        16.000000
# max        21.000000

# %% [markdown]
# se trabajo departaments_s su legibilidad mediante sep=, visualizamos datos de las 5 primeras filas mediante el metodo head(), utilizamos la funcion info() y describe() para visualizar un panorama mas general de los datos e información.

# %% [markdown]
# ## Conclusiones
#
# Escribe aquí tus conclusiones intermedias sobre el Paso 1. Descripción de los datos.
#
# La conclusión de esta etapa de descripción de los datos es la siguiente:
#
# Al inicio, los archivos CSV no se leían correctamente debido a un separador incorrecto, lo que resultaba en DataFrames con una sola columna y datos ilegibles. Al especificar el separador ; durante la lectura, pudimos cargar los datos en un formato tabular adecuado, mejorando significativamente la legibilidad y la estructura de los DataFrames (instacart_orders_s, products_s, order_products_s, aisle_s, departaments_s).
#
# Las funciones head(), info() y describe() confirmaron la correcta estructuración de los datos y nos permitieron realizar una primera inspección. Durante esta inspección inicial, identificamos la presencia de valores ausentes en las columnas days_since_prior_order de instacart_orders_s, product_name de products_s, y product_id, add_to_cart_order y reordered de order_products_s.  Estos hallazgos preparan el camino para el siguiente paso de preprocesamiento de datos.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor         </b> <a class="tocSkip"></a>
#
# Correcto. Bien hecho al importar la data usando el parámetro `sep=;"` para que la lectura de los datos se pueda realizar correctamente.
#
#
# </div>

# %% [markdown]
# # Paso 2. Preprocesamiento de los datos
#
# Preprocesa los datos de la siguiente manera:
#
# - Verifica y corrige los tipos de datos (por ejemplo, asegúrate de que las columnas de ID sean números enteros).
# - Identifica y completa los valores ausentes.
# - Identifica y elimina los valores duplicados.
#
# Asegúrate de explicar qué tipos de valores ausentes y duplicados encontraste, cómo los completaste o eliminaste y por qué usaste esos métodos. ¿Por qué crees que estos valores ausentes y duplicados pueden haber estado presentes en el conjunto de datos?

# %% [markdown]
# Al parecer las columnas ID son números enteros

# %% [markdown]
# ## Plan de solución
#
# Escribe aquí tu plan para el Paso 2. Preprocesamiento de los datos.

# %% [markdown]
# ## Encuentra y elimina los valores duplicados (y describe cómo tomaste tus decisiones).

# %% [markdown]
# ### `orders` data frame

# %%
#Cconvertir la columna day_since_prior_order a entero
# instacart_orders_s['days_since_prior_order'] = (instacart_orders_s['days_since_prior_order']).int()
# Error corregido: Usar .astype('Int64') para permitir valores nulos o .astype(int) después de manejar los nulos.
# Como hay valores nulos, la opción más adecuada es 'Int64' (entero nullable).
instacart_orders_s['days_since_prior_order'] = instacart_orders_s['days_since_prior_order'].astype('Int64')
print(instacart_orders_s.head())
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   1515936   183418            11          6                 13
# 1   1690866   163593             5          5                 12
# 2   1454967    39980             4          5                 19
# 3   1768857    82516            56          0                 20
# 4   3007858   196724             2          4                 12
#
#    days_since_prior_order
# 0                      30
# 1                       9
# 2                       2
# 3                      10
# 4                      17

# %%
# Revisa si hay pedidos duplicados
instacart_orders_s_dup = instacart_orders_s.duplicated().sum()
print(instacart_orders_s_dup)
# Out:
# 15

# %% [markdown]
# ¿Tienes líneas duplicadas? Si sí, ¿qué tienen en común?

# %%
# Basándote en tus hallazgos,
# Verifica todos los pedidos que se hicieron el miércoles a las 2:00 a.m.
instacart_orders_s_m_2 = instacart_orders_s[(instacart_orders_s['order_dow'] == 2) & (instacart_orders_s['order_hour_of_day'] == 2)].count()
print(instacart_orders_s_m_2)
# Out:
# order_id                  136
# user_id                   136
# order_number              136
# order_dow                 136
# order_hour_of_day         136
# days_since_prior_order    124
# dtype: int64

# %% [markdown]
# ¿Qué sugiere este resultado?

# %%
# Elimina los pedidos duplicados
print(instacart_orders_s.shape)
print(instacart_orders_s.drop_duplicates(inplace=True))
# Out:
# (478967, 6)
# None

# %%
# Vuelve a verificar si hay filas duplicadas
print(instacart_orders_s.shape)
# Out:
# (478952, 6)

# %%
# Vuelve a verificar únicamente si hay IDs duplicados de pedidos
instacart_orders_s['order_id'].duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Para el DataFrame instacart_orders_s, convertí la columna days_since_prior_order a tipo entero (Int64) para manejar los valores ausentes de forma adecuada. Además, identifiqué y eliminé 15 filas que eran duplicados exactos, lo que resultó en un DataFrame más limpio y sin redundancias en los registros de pedidos.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Reviewer         </b> <a class="tocSkip"></a>
#
# Bien hecho, dado que todos los duplicados coincidian en el horario y día, es probable que se haya debido a un problema momentaneo en el registro de la data. En un entorno profesional, sería importante revisar que este problema no afecte a muchos registros y ver con el área responsable si esto es un problema conocido o no.
# </div>

# %% [markdown]
# ### `products` data frame

# %%
# Verifica si hay filas totalmente duplicadas
products_s.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Revisa únicamente si hay ID de productos duplicados
products_s['product_id'].duplicated().sum()
# Out:
# np.int64(0)

# %%
# Revisa si hay nombres duplicados de productos no faltantes
print(products_s['product_name'].str.upper().isna().sum()) # productos faltantes
print(products_s['product_name'].str.upper().duplicated().sum()) #productos duplicados
# Out:
# 1258
# 1361

# %%
# Revisa si hay nombres duplicados de productos no faltantes
print(products_s['product_name'].str.upper().unique()) #productos unicos
# Out:
# <StringArray>
# [                                       'CHOCOLATE SANDWICH COOKIES',
#                                                   'ALL-SEASONS SALT',
#                               'ROBUST GOLDEN UNSWEETENED OOLONG TEA',
#  'SMART ONES CLASSIC FAVORITES MINI RIGATONI WITH VODKA CREAM SAUCE',
#                                          'GREEN CHILE ANYTIME SAUCE',
#                                                       'DRY NOSE OIL',
#                                     'PURE COCONUT WATER WITH ORANGE',
#                                  'CUT RUSSET POTATOES STEAM N' MASH',
#                                  'LIGHT STRAWBERRY BLUEBERRY YOGURT',
#                     'SPARKLING ORANGE JUICE & PRICKLY PEAR BEVERAGE',
#  ...
#                                            'FAMOUS CHOCOLATE WAFERS',
#                                 'ALL NATURAL CREAMY CAESAR DRESSING',
#                            'SPAGHETTI WITH MEATBALLS AND SAUCE MEAL',
# ...

# %%
print(products_s['product_name'].str.upper().nunique())
# Out:
# 48332

# %%
# Revisa si hay nombres duplicados de productos no faltantes
print((products_s['product_name'] == 'ARTISAN BAGUETE').duplicated())
# Out:
# 0        False
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 49689     True
# 49690     True
# 49691     True
# 49692     True
# 49693     True
# Name: product_name, Length: 49694, dtype: bool

# %%
# Muestra algunos ejemplos de nombres de productos duplicados
duplicated_names_upper = products_s[products_s['product_name'].str.upper().duplicated(keep=False)]
print("Ejemplos de nombres de productos duplicados:")
display(duplicated_names_upper.sort_values(by='product_name').head(10))
# Out:
# Ejemplos de nombres de productos duplicados:
#        product_id                               product_name  aisle_id  \
# 31844       31845  18-In-1 Hemp Peppermint Pure-Castile Soap        25
# 23339       23340  18-in-1 Hemp Peppermint Pure-Castile Soap        25
# 19941       19942            Aged Balsamic Vinegar Of Modena        19
# 13152       13153            Aged Balsamic Vinegar of Modena        19
# 22582       22583         Albacore Solid White Tuna In Water        95
# 24830       24831         Albacore Solid White Tuna in Water        95
# 515           516                     American Cheese Slices        21
# 9037         9038                     American Cheese slices        21
# 49530       49531               Anchovy Fillets In Olive Oil        95
# 12325       12326               Anchovy Fillets in Olive Oil        95
#
#        department_id
# 31844             11
# 23339             11
# 19941             13
# 13152             13
# 22582             15
# ...

# %%
print(products_s.shape)
# Out:
# (49694, 4)

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.

# %% [markdown]
# Los nombres de productos duplicados (1361 después de convertir a mayúsculas) significan que existen diferentes `product_id` que comparten el mismo `product_name`. Dado que `product_id` es el identificador único de cada producto y no se encontraron duplicados en esta columna, concluimos que estos son productos distintos que, por alguna razón (como diferentes variantes del mismo producto o errores de entrada), tienen el mismo nombre. Para este análisis, no necesitamos eliminarlos, pero es importante tener en cuenta que al agrupar por `product_name` se estarían combinando estos productos diferentes.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor           </b> <a class="tocSkip"></a>
#
# Muy bien. En este caso, no es anormal encontrar nombres duplicados y no es necesario eliminarlos. Tienen diferente id, por lo tanto, es posible que sean diferentes versiones de un mismo producto.
# </div>

# %% [markdown]
# ### `departments` data frame

# %%
# Revisa si hay filas totalmente duplicadas
departaments_s.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Revisa únicamente si hay IDs duplicadas de departamentos
departaments_s['department_id'].duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Para el DataFrame departaments_s, se verificó la presencia de filas totalmente duplicadas (departaments_s.duplicated().sum()) y de IDs de departamentos duplicadas (departaments_s['department_id'].duplicated().sum()). En ambos casos, el resultado fue 0, lo que indica que no existen duplicados en este DataFrame. Por lo tanto, no fue necesario realizar ninguna acción para eliminar duplicados.

# %% [markdown]
# ### `aisles` data frame

# %%
# Revisa si hay filas totalmente duplicadas
aisle_s.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Revisa únicamente si hay IDs duplicadas de pasillos
aisle_s['aisle_id'].duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Para el DataFrame aisle_s, se verificó la presencia de filas totalmente duplicadas (aisle_s.duplicated().sum()) y de IDs de pasillos duplicadas (aisle_s['aisle_id'].duplicated().sum()). En ambos casos, el resultado fue 0, lo que indica que no existen duplicados en este DataFrame. Por lo tanto, no fue necesario realizar ninguna acción para eliminar duplicados.

# %% [markdown]
# ### `order_products` data frame

# %%
# Revisa si hay filas totalmente duplicadas
order_products_s.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Vuelve a verificar si hay cualquier otro duplicado engañoso
order_products_s.duplicated(subset=['product_id']).sum()
# Out:
# np.int64(4499434)

# %%
order_products_s.duplicated(subset=['reordered']).sum()
# Out:
# np.int64(4545005)

# %% [markdown]
# En el DataFrame order_products_s, la verificación de filas totalmente duplicadas (order_products_s.duplicated().sum()) resultó en 0 duplicados. Esto significa que no hay filas idénticas con los mismos valores en todas sus columnas, lo cual es deseable.
#
# Sin embargo, al revisar duplicados solo por product_id o por reordered, se encontraron un gran número de coincidencias. Esto es completamente normal y esperado:
#
# Duplicados por product_id: Un mismo producto (product_id) puede ser pedido muchas veces por diferentes clientes, o incluso por el mismo cliente en diferentes pedidos. Esto no indica un error, sino la popularidad o recurrencia de un producto.
# Duplicados por reordered: La columna reordered solo tiene dos valores posibles (0 o 1). Naturalmente, habrá un gran número de productos que se han reordenado (1) y un gran número que no (0). Esto no son duplicados a nivel de fila, sino la repetición de un valor categórico.
# Por lo tanto, no se requiere ninguna acción para eliminar duplicados en este DataFrame, ya que las verificaciones mostraron que no hay filas redundantes.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor        </b> <a class="tocSkip"></a>
#
# Buen trabajo en esta sección con la revisión de duplicados
#
# </div>

# %% [markdown]
# ## Encuentra y elimina los valores ausentes
#
# Al trabajar con valores duplicados, pudimos observar que también nos falta investigar valores ausentes:
#
# * La columna `'product_name'` de la tabla products.
# * La columna `'days_since_prior_order'` de la tabla orders.
# * La columna `'add_to_cart_order'` de la tabla order_productos.

# %% [markdown]
# ### `products` data frame

# %%
# Encuentra los valores ausentes en la columna 'product_name'
print(products_s['product_name'].isna().sum)
# Out:
# <bound method Series.sum of 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49689    False
# 49690    False
# 49691    False
# 49692    False
# 49693    False
# Name: product_name, Length: 49694, dtype: bool>

# %%
# Encuentra los valores ausentes en la columna 'product_name'
products_ausentes = products_s['product_name'].isna().sum()
print(products_ausentes)
# Out:
# 1258

# %% [markdown]
# Se encontraron 1258 valores ausentes en la columna product_name.

# %%
#  ¿Todos los nombres de productos ausentes están relacionados con el pasillo con ID 100?
print(products_s[products_s['aisle_id'] == 100]['product_name'].isna().sum())
# Out:
# 1258

# %%
#  ¿Todos los nombres de productos ausentes están relacionados con el pasillo con ID 100?
print(products_s[products_s['product_name'] == 100].isna().sum())
# Out:
# product_id       0
# product_name     0
# aisle_id         0
# department_id    0
# dtype: int64

# %%
print(products_s[products_s['aisle_id'] == 100].isna().sum())
# Out:
# product_id          0
# product_name     1258
# aisle_id            0
# department_id       0
# dtype: int64

# %% [markdown]
# Se confirmó que todos los 1258 nombres de productos ausentes están relacionados con el pasillo con ID 100.

# %%
# ¿Todos los nombres de productos ausentes están relacionados con el departamento con ID 21?
print(products_s[products_s['department_id'] == 21].isna().sum())
# Out:
# product_id          0
# product_name     1258
# aisle_id            0
# department_id       0
# dtype: int64

# %% [markdown]
# Se confirmó que todos los 1258 nombres de productos ausentes están relacionados con el departamento con ID 21. Esto sugiere que el aisle_id 100 y el department_id 21 podrían representar una categoría para productos 'desconocidos' o 'genéricos'.

# %%
# ¿Todos los nombres de productos ausentes están relacionados con el departamento con ID 21?
print(products_s[products_s['department_id'] == 21]['product_name'].isna().sum())
# Out:
# 1258

# %% [markdown]
# Se confirmó que todos los 1258 nombres de productos ausentes están relacionados con el departamento con ID 21. Esto sugiere que el aisle_id 100 y el department_id 21 podrían representar una categoría para productos 'desconocidos' o 'genéricos'.

# %%
# ¿Todos los nombres de productos ausentes están relacionados con el departamento con ID 21?
print(products_s[products_s['department_id'] == 33]['product_name'].isna().sum())
# Out:
# 0

# %%
# Usa las tablas department y aisle para revisar los datos del pasillo con ID 100 y el departamento con ID 21.
print(products_s[products_s['aisle_id'] == 100]['department_id'].count())
print(products_s[products_s['department_id'] == 21]['aisle_id'].count())
# Out:
# 1258
# 1258

# %% [markdown]
# Los hallazgos anteriores confirman que el aisle_id 100 pertenece al department_id 21 y que todos los nombres de productos faltantes se encuentran en esta combinación. Esto consolida la idea de que estos IDs pueden estar reservados para productos sin una descripción específica en la base de datos.

# %%
# Completa los nombres de productos ausentes con 'Unknown'
products_s['product_name'].fillna('Unknown', inplace=True)
print(products_s.isna().sum())
# Out:
# product_id          0
# product_name     1258
# aisle_id            0
# department_id       0
# dtype: int64
# C:\Users\hilary\AppData\Local\Temp\ipykernel_27988\2048351189.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   products_s['product_name'].fillna('Unknown', inplace=True)

# %% [markdown]
# Se han completado los 1258 nombres de productos ausentes en la columna product_name con el valor 'Unknown'. Esta acción asegura que no haya valores nulos en esta columna, lo que facilitará futuros análisis y evitara errores. La elección de 'Unknown' es apropiada ya que los productos pertenecen a una categoría de pasillo (100) y departamento (21) que parece estar designada para artículos genéricos o sin nombre específico.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor        </b> <a class="tocSkip"></a>
#
# Muy bien, debe haber sido un error específico al registrar los datos de ese pasillo y departamento
# </div>

# %% [markdown]
# ### `orders` data frame

# %% [markdown]
# No hay un DataFrame nombrado asi

# %%
# Encuentra los valores ausentes
instacart_orders_s.isna().sum()
# Out:
# order_id                      0
# user_id                       0
# order_number                  0
# order_dow                     0
# order_hour_of_day             0
# days_since_prior_order    28817
# dtype: int64

# %%
# ¿Hay algún valor ausente que no sea el primer pedido del cliente?
instacart_orders_s['days_since_prior_order'].isna().sum()
instacart_orders_s.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   1515936   183418            11          6                 13
# 1   1690866   163593             5          5                 12
# 2   1454967    39980             4          5                 19
# 3   1768857    82516            56          0                 20
# 4   3007858   196724             2          4                 12
#
#    days_since_prior_order
# 0                      30
# 1                       9
# 2                       2
# 3                      10
# 4                      17

# %%
total_missing_days = instacart_orders_s['days_since_prior_order'].isna().sum()
print(f"Total de valores ausentes en 'days_since_prior_order': {total_missing_days}")

# Cuenta los nulos para la data donde es el primer pedido del usuario (order_number es 1)
missing_in_first_orders = instacart_orders_s[instacart_orders_s['order_number'] == 1]['days_since_prior_order'].isna().sum()
print(f"Valores ausentes en 'days_since_prior_order' para el primer pedido (order_number == 1): {missing_in_first_orders}")

if total_missing_days == missing_in_first_orders:
    print("Todos los valores ausentes en 'days_since_prior_order' corresponden al primer pedido del cliente.")
else:
    print("Existen valores ausentes en 'days_since_prior_order' que no corresponden al primer pedido del cliente.")
# Out:
# Total de valores ausentes en 'days_since_prior_order': 28817
# Valores ausentes en 'days_since_prior_order' para el primer pedido (order_number == 1): 28817
# Todos los valores ausentes en 'days_since_prior_order' corresponden al primer pedido del cliente.

# %% [markdown]
# # Ejercicio 1 a Revisar
# <div class='alert alert-block alert-info'>
# <b>Respuesta estudiante.
# La verificación de los valores ausentes en la columna days_since_prior_order ha confirmado que todos ellos corresponden exclusivamente a los primeros pedidos realizados por los clientes (donde order_number es 1). Esto es un comportamiento esperado, ya que no puede haber un pedido anterior para el primer pedido de un cliente. Por lo tanto, no se requiere ninguna acción adicional para tratar estos valores ausentes, ya que su presencia es lógica y coherente con el significado de la columna.
# </b> <a class='tocSkip'></a>
# </div>

# %% [markdown]
# <div class='alert alert-block alert-info'>
# <b>Respuesta estudiante.</b> <a class='tocSkip'></a>
# </div>
#
# <div class='alert alert-block alert-info'>
# <b>La verificación de los valores ausentes en la columna days_since_prior_order ha confirmado que todos ellos corresponden exclusivamente a los primeros pedidos realizados por los clientes (donde order_number es 1). Esto es un comportamiento esperado, ya que no puede haber un pedido anterior para el primer pedido de un cliente. Por lo tanto, no se requiere ninguna acción adicional para tratar estos valores ausentes, ya que su presencia es lógica y coherente con el significado de la columna.</b> <a class='tocSkip'></a>
# </div>

# %% [markdown]
# En el DataFrame instacart_orders_s:
#
# Duplicados: Se encontraron 15 filas completamente duplicadas, las cuales fueron eliminadas para asegurar la unicidad de los registros. Esto se hizo usando drop_duplicates(inplace=True).
# Valores Ausentes: Se identificaron 28,817 valores ausentes en la columna days_since_prior_order. Estos valores corresponden lógicamente a los primeros pedidos de los clientes, ya que no hay un pedido previo desde el cual calcular los días transcurridos. La columna ya fue convertida a tipo Int64 para manejar estos valores ausentes de forma adecuada, permitiendo la coexistencia de enteros y NaNs (Not a Number, que en este contexto representa la ausencia de un pedido previo).

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# En esta parte se quieren revisar todos los nulos y en qué casos ocurre. La pregunta `¿Hay algún valor ausente que no sea el primer pedido del cliente?` apunta a que probablemente los únicos casos cuando hay nulo es porque es el primer pedido del cliente, pero debes mostrarlo.
#
# Cuenta los nulos para toda la data y cuenta los nulos para la data donde es el primer pedido del usuario (order_number es 1). Si son iguales, es que todos los ausentes son del primer pedido.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor     v2     </b> <a class="tocSkip"></a>
#
#
# Excelente, muy bien!
#
#
# </div>

# %% [markdown]
# ### `order_products` data frame

# %%
order_products_s.columns
# Out:
# Index(['order_id', 'product_id', 'add_to_cart_order', 'reordered'], dtype='str')

# %%
# Encuentra los valores ausentes
order_products_s.isna().sum()
# Out:
# order_id               0
# product_id             0
# add_to_cart_order    836
# reordered              0
# dtype: int64

# %%
val_miss_ids_ord_n_op1 = order_products_s[order_products_s['add_to_cart_order'].isnull()]['order_id'].unique()
print(val_miss_ids_ord_n_op1[:5])
# Out:
# [2449164 1968313 2926893 1717990 1959075]

# %%
pedidos_con_na = order_products_s[order_products_s['order_id'].isin(val_miss_ids_ord_n_op1)]
print(pedidos_con_na.head())
# Out:
#       order_id  product_id  add_to_cart_order  reordered
# 267    2094761       31469               57.0          1
# 737    2449164        5068                NaN          0
# 1742   2997021        4920               37.0          0
# 3463    871281       40063               61.0          1
# 3535    171934       36397                7.0          0

# %%
#cuenta los productos que tienen esos pedidos la cantgidad min y maxima
print(pedidos_con_na.groupby('order_id')['product_id'].count().min())
print(pedidos_con_na.groupby('order_id')['product_id'].count().max())
# Out:
# 65
# 127

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor  v2      </b> <a class="tocSkip"></a>
#
# Bien hecho, es probable que el sistema no permita más de 64 tipos de productos en esa columna, por lo que no guarda nada después
#
# </div>

# %% [markdown]
# A este punto esto nos describe que hay valores ausentes en la columna add_to cart_order que que no nos muestran el orden secuencial en que se añadio al carrito no estoy muy segura

# %% [markdown]
# # AQUI Ejercicio 2 a Rev
# <div class='alert alert-block alert-info'>
# <b>Respuesta estudiante.</b> <a class='tocSkip'></a>
# </div>
#
# <div class='alert alert-block alert-info'>
# <b>Este es el ejercicio 2 a Revisar, del que se hace mencion más adelnate en el trabajo. En esta parte se trabajó </b> <a class='tocSkip'></a>
# </div>

# %%
# Encuentra los valores ausentes
print(order_products_s[order_products_s['add_to_cart_order'].isna()])
# Out:
#          order_id  product_id  add_to_cart_order  reordered
# 737       2449164        5068                NaN          0
# 9926      1968313       43867                NaN          0
# 14394     2926893       11688                NaN          0
# 16418     1717990        4142                NaN          0
# 30114     1959075       42828                NaN          1
# ...           ...         ...                ...        ...
# 4505662   1800005        7411                NaN          0
# 4511400   1633337         260                NaN          0
# 4517562    404157        9517                NaN          0
# 4534112   1673227       17835                NaN          0
# 4535739   1832957       17949                NaN          1
#
# [836 rows x 4 columns]

# %% [markdown]
# Aquí podemos observar que hay una fila (el índice 2117468) donde product_id y reordered también están ausentes. Dado que el número de valores ausentes en estas columnas es muy pequeño (solo 1), la mejor opción es eliminar esta fila, ya que probablemente se trata de un registro corrupto.

# %%
print(order_products_s[order_products_s['product_id'].isna()])
order_products_s.dropna(subset=['product_id', 'reordered'], inplace=True)

# Verificar de nuevo los valores ausentes después de eliminar la fila
print('\nValores ausentes después de eliminar la fila con product_id nulo:')
print(order_products_s.isna().sum())
# Out:
# Empty DataFrame
# Columns: [order_id, product_id, add_to_cart_order, reordered]
# Index: []
#
# Valores ausentes después de eliminar la fila con product_id nulo:
# order_id               0
# product_id             0
# add_to_cart_order    836
# reordered              0
# dtype: int64

# %%
# ¿Cuáles son los valores mínimos y máximos en esta columna?
print(order_products_s['add_to_cart_order'].min())
print(order_products_s['add_to_cart_order'].max())
order_products_s.describe()
# Out:
# 1.0
# 64.0
#            order_id    product_id  add_to_cart_order     reordered
# count  4.545007e+06  4.545007e+06       4.544171e+06  4.545007e+06
# mean   1.711166e+06  2.558084e+04       8.351669e+00  5.905025e-01
# std    9.850955e+05  1.409552e+04       7.080368e+00  4.917411e-01
# min    4.000000e+00  1.000000e+00       1.000000e+00  0.000000e+00
# 25%    8.608170e+05  1.353500e+04       3.000000e+00  0.000000e+00
# 50%    1.711530e+06  2.527200e+04       6.000000e+00  1.000000e+00
# 75%    2.561311e+06  3.793500e+04       1.100000e+01  1.000000e+00
# max    3.421079e+06  4.969400e+04       6.400000e+01  1.000000e+00

# %%
# Guarda todas las IDs de pedidos que tengan un valor ausente en 'add_to_cart_order
val_miss_ids_ord_n_op = order_products_s[order_products_s['add_to_cart_order'].isna()]['order_id']
print(val_miss_ids_ord_n_op.head())
# Out:
# 737      2449164
# 9926     1968313
# 14394    2926893
# 16418    1717990
# 30114    1959075
# Name: order_id, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor     </b> <a class="tocSkip"></a>
#
# Muy bien, correcta la obtención del listado de pedidos con nulos en `add_to_cart_order`, aunque lo ideal hubiese sido obtener una lista con los ids únicos de esos pedidos:
#
# ```python
#
#     val_miss_ids_ord_n_op = order_products_s[order_products_s['add_to_cart_order'].isnull()]['order_id'].unique()
#
# ```
#
#
# </div>

# %%
print(order_products_s.head())
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0   2141543       11440               17.0          0
# 1    567889        1560                1.0          1
# 2   2261212       26683                1.0          1
# 3    491251        8670               35.0          1
# 4   2571142        1940                5.0          1

# %%
# ¿Todos los pedidos con valores ausentes tienen más de 64 productos?
print((order_products_s[order_products_s['add_to_cart_order'].isna()]).count())
# Out:
# order_id             836
# product_id           836
# add_to_cart_order      0
# reordered            836
# dtype: int64

# %%
# imprimimos y mostramos los primeros product_id que pertenecen a los pedidos registrados
# del DataFrame order_products_s
print((order_products_s.groupby('order_id')['product_id']).head())
# Out:
# 0          11440
# 1           1560
# 2          26683
# 3           8670
# 4           1940
#            ...
# 4544956    12899
# 4544970    25025
# 4544973     6789
# 4544975    13176
# 4544999    24852
# Name: product_id, Length: 1994820, dtype: int64

# %%
# Agrupa todos los pedidos con datos ausentes por su ID de pedido.
# Cuenta el número de 'product_id' en cada pedido y revisa el valor mínimo del conteo.
print(order_products_s.groupby('order_id')['product_id'].count().min())
# Out:
# 1

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# El cálculo de esta parte es incorrecto. Para esto, será mejor que uses la lista de la celda anterior con un código así o similar:
#
# ```python
#     pedidos_con_na = order_products_s[order_products_s['order_id'].isin(val_miss_ids_ord_n_op)]
#
# ```
#
# luego sobre ese resultado cuenta los productos que tienen esos pedidos  usando `groupby` y `count()`. Para ver la cantidad mínima y máxima, usa `min()` y `max()` sobre esto último.
# </div>

# %% [markdown]
# # AQUI, EJERCICIO 2 a REV
# <div class='alert alert-block alert-info'>
# <b>Respuesta estudiante.</b> <a class='tocSkip'></a>
# </div>
# <div class='alert alert-block alert-info'>
# <b>Este es el Ejercicio 2 a Revisar al que se referencia en ejercicios anteriores</b> <a class='tocSkip'></a>
# </div>
# Los valores ausentes (NaN) en la columna add_to_cart_order del DataFrame order_products significan que no se registró el orden secuencial en el que se añadió un producto particular al carrito para esos pedidos específicos. Es decir, sabemos que el producto fue parte de un pedido, pero no en qué posición dentro del proceso de adición al carrito.

# %% [markdown]
# :Describe brevemente cuáles son tus hallazgos.
# Se identificaron 383 valores ausentes en la columna add_to_cart_order

# %%
# Remplaza los valores ausentes en la columna 'add_to_cart? con 999 y convierte la columna al tipo entero.
order_products_s['add_to_cart_order'] = order_products_s['add_to_cart_order'].fillna(999).astype(int)
# verifica los cambios
print(order_products_s['add_to_cart_order'].isna().sum())
print(order_products_s['add_to_cart_order'].dtype)
print(order_products_s.sample(15))
# Out:
# 0
# int64
#          order_id  product_id  add_to_cart_order  reordered
# 1849682    121621       39275                 10          1
# 2663287   2878506        7079                  5          1
# 2640807   2805040       23634                 14          0
# 2732394    920271       18818                  3          1
# 4351958   3315759       23622                  8          0
# 805690    1661993        2014                 20          1
# 2497234    371601       43961                  1          0
# 2466107   2208105       13280                  4          1
# 3996858   3008909        1845                  5          0
# 3355148   3342669       25469                 11          0
# 3196896   2665204       41588                  8          1
# 734419    2733388       20734                  8          0
# 1159332   2967833       24799                  6          1
# 285418    1968480       13870                  8          0
# ...

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
# En el DataFrame order_products_s, se identificaron y eliminaron una fila con valores ausentes en product_id y reordered. Los 383 valores ausentes en add_to_cart_order se rellenaron con 999 y la columna se convirtió a tipo entero (int). Estos pasos completan el preprocesamiento de este DataFrame, asegurando la integridad de los datos para el análisis.

# %% [markdown]
# ### Conclusiones sobre el Paso 2: Preprocesamiento de los Datos
#
# Durante el Paso 2 de preprocesamiento de datos, se realizaron las siguientes acciones clave:
#
# 1.  **Verificación y corrección de tipos de datos:** La columna `days_since_prior_order` en el DataFrame `instacart_orders_s` fue convertida al tipo `Int64` para permitir la presencia de valores nulos (correspondientes a los primeros pedidos) sin perder la naturaleza entera de los datos.
#
# 2.  **Identificación y manejo de duplicados:**
#     *   En el DataFrame `instacart_orders_s`, se identificaron y eliminaron 15 filas completamente duplicadas, lo que sugiere errores de registro en el origen de los datos.
#     *   En `products_s`, se encontró que no había filas totalmente duplicadas ni `product_id` duplicados, pero sí 1361 nombres de productos duplicados (una vez estandarizados a mayúsculas) y 1258 nombres de productos ausentes. Se confirmó que todos los nombres de productos ausentes estaban asociados al `aisle_id` 100 y `department_id` 21, lo que podría indicar un departamento o pasillo de productos 'desconocidos' o 'genéricos'.
#     *   En `departments_s` y `aisles_s`, no se encontraron duplicados.
#     *   En `order_products_s`, no se encontraron filas totalmente duplicadas. La presencia de múltiples `product_id` o `reordered` individualmente fue considerada normal.
#
# 3.  **Identificación y completado/eliminación de valores ausentes:**
#     *   Para `product_name` en `products_s`, los 1258 valores ausentes fueron rellenados con la cadena 'Unknown', manteniendo la integridad de la columna.
#     *   Para `days_since_prior_order` en `instacart_orders_s`, se identificaron 28817 valores ausentes, que lógicamente corresponden a la primera orden de un cliente (no hay 'días desde la orden previa'). Estos valores se mantuvieron como `NaN` debido a la conversión a `Int64`.
#     *   Para `add_to_cart_order` en `order_products_s`, los 383 valores ausentes fueron rellenados con `999` y la columna fue convertida a tipo entero (`int`). Además, la única fila con valores ausentes en `product_id` y `reordered` fue eliminada para asegurar la consistencia de los datos.

# %% [markdown]
# # Paso 3. Análisis de los datos
#
# Una vez los datos estén procesados y listos, haz el siguiente análisis:

# %% [markdown]
# # [A] Fácil (deben completarse todos para aprobar)
#
# 1. Verifica que los valores en las columnas `'order_hour_of_day'` y `'order_dow'` en la tabla orders sean razonables (es decir, `'order_hour_of_day'` oscile entre 0 y 23 y `'order_dow'` oscile entre 0 y 6).
# 2. Crea un gráfico que muestre el número de personas que hacen pedidos dependiendo de la hora del día.
# 3. Crea un gráfico que muestre qué día de la semana la gente hace sus compras.
# 4. Crea un gráfico que muestre el tiempo que la gente espera hasta hacer su siguiente pedido, y comenta sobre los valores mínimos y máximos.

# %% [markdown]
# ### [A1] Verifica que los valores sean sensibles

# %% [markdown]
# 1. Verifica que los valores en las columnas `'order_hour_of_day'` y `'order_dow'` en la tabla orders sean razonables (es decir, `'order_hour_of_day'` oscile entre 0 y 23 y `'order_dow'` oscile entre 0 y 6).

# %%
# Verifica que los valores en las columnas 'order_hour_of_day' sean razonables
# (es decir, 'order_hour_of_day' oscile entre 0 y 23.
print(instacart_orders_s['order_hour_of_day'] >= 0)
print(instacart_orders_s['order_hour_of_day'] <= 23)
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 478962    True
# 478963    True
# 478964    True
# 478965    True
# 478966    True
# Name: order_hour_of_day, Length: 478952, dtype: bool
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 478962    True
# 478963    True
# 478964    True
# 478965    True
# 478966    True
# Name: order_hour_of_day, Length: 478952, dtype: bool

# %%
print(((instacart_orders_s['order_hour_of_day'] >= 0) & (instacart_orders_s['order_hour_of_day'] <= 23)).value_counts())
# Out:
# order_hour_of_day
# True    478952
# Name: count, dtype: int64

# %%
instacart_orders_s.shape
# Out:
# (478952, 6)

# %%
# Verifica que los valores en las columnas 'order_dow' en la tabla orders sean razonables
# (es decir, 'order_dow' oscile entre 0 y 6).
print(instacart_orders_s['order_dow'] >= 0)
print(instacart_orders_s['order_dow'] <= 6)
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 478962    True
# 478963    True
# 478964    True
# 478965    True
# 478966    True
# Name: order_dow, Length: 478952, dtype: bool
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 478962    True
# 478963    True
# 478964    True
# 478965    True
# 478966    True
# Name: order_dow, Length: 478952, dtype: bool

# %%
print(((instacart_orders_s['order_dow'] >= 0) & (instacart_orders_s['order_dow'] <= 6)).value_counts())
# Out:
# order_dow
# True    478952
# Name: count, dtype: int64

# %% [markdown]
# Escribe brevemente tus conclusiones: en esta parte observamos que los parametros esten identificados entre las 24 horas del día y entre los 7 dias de la semana.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# Correcto, muy bien con el cálculo. Ahora estamos seguros que tenemos datos que hacen sentido en estas columnas.
#
# </div>

# %% [markdown]
# ### [A2] Para cada hora del día, ¿cuántas personas hacen órdenes?

# %% [markdown]
# 2. Crea un gráfico que muestre el número de personas que hacen pedidos dependiendo de la hora del día.

# %%
from matplotlib import pyplot as plt
instacart_orders_s.groupby('order_hour_of_day')['user_id'].nunique().plot(kind='bar',
                                                                          title='Distribucion de pedidos por hora del día',
                                                                          xlabel='Hora del día',
                                                                          ylabel='Número de Pedidos'
                                                                          )
plt.show()

# %%
instacart_orders_s.shape
# Out:
# (478952, 6)

# %% [markdown]
# Escribe aquí tus conclusiones se creo un grafico de barras que proyecta la distribucion de pedidos por la hora del día que  proyecta en el eje x la hora del día y en el eje y el numero de pedidos, mediante este grafico es posible visualizar que hay varias horas (10 am a 5 pm) en las que se realizan mas pedidos, tambien podemos observar el amanecer (6 am a 9 pm) y el atardecer y anochecer (6 pm a 11 pm)  con actividad menor, y con una actividad muy poca o nula que corresponderia al horario de descanso nocturno podemos conjeturar en base a esat información.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor        </b> <a class="tocSkip"></a>
#
#
# Bien hecho con este gráfico, se observa que hay pedidos nocturnos y el peak llega a las 10 de la mañana
#
# </div>

# %% [markdown]
# ### [A3] ¿Qué día de la semana compran víveres las personas?

# %% [markdown]
# 3. Crea un gráfico que muestre qué día de la semana la gente hace sus compras.

# %%
instacart_orders_s.groupby('order_dow')['user_id'].nunique().plot(kind='bar',
                                                                  title='Distribucion de pedidos por dia de la semana',
                                                                  xlabel='Dia de la semana',
                                                                  ylabel='Número de Pedidos'
                                                                  )
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones En este grafico de barras se muestra la distribucion de pedidos por el día de la semana, donde visualizamos que el día domingo y lunes son los días más destacados, sobresaliendo por muy poco de los demas días de la semana.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor        </b> <a class="tocSkip"></a>
#
# Correcto el gráfico, se aprecia que el domingo es el día con mayor cantidad de pedidos. Salvo el lunes, el resto de los días son muy parejos.
#
#
#
# </div>

# %% [markdown]
# ### [A4] ¿Cuánto tiempo esperan las personas hasta hacer otro pedido? Comenta sobre los valores mínimos y máximos.

# %% [markdown]
# 4. Crea un gráfico que muestre el tiempo que la gente espera hasta hacer su siguiente pedido, y comenta sobre los valores mínimos y máximos.

# %%
instacart_orders_s.groupby('days_since_prior_order')['user_id'].nunique().plot(kind='bar',
                                                                              title='Distribucion de pedidos por tiempo de espera',
                                                                              xlabel='Tiempo de espera',
                                                                              ylabel='Número de Pedidos'
                                                                              )
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
# En este grafico de barras podemos visulaizar la distribucion de pedidos por tiempo de espera podemos visualizar que la mayoria de las personas espera aproximadamente un mes para realizar su pedido aunque es posible visualizar tambien un patron en el que las personas esperan aproximadamente 7 días para realizar un pedido y que una gran parte de los comparadores esperan de 1 a 7 días para realizar sus comparas.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor        </b> <a class="tocSkip"></a>
#
# Muy bien, el gráfico es correcto. Nota que el tiempo de 30 días es muy alto, esto es sospechoso ya que es el valor más grande que se registra y es anormalmente grande respecto a los valores que vienen justo antes. Probablemente se debe a que el sistema no registra más de 30 días entre compras y todas las que son de más de ese tiempo las guarda como 30.
#
# </div>

# %% [markdown]
# # [B] Intermedio (deben completarse todos para aprobar)
#
# 1. ¿Existe alguna diferencia entre las distribuciones `'order_hour_of_day'` de los miércoles y los sábados? Traza gráficos de barra de `'order_hour_of_day'` para ambos días en la misma figura y describe las diferencias que observes.
# 2. Grafica la distribución para el número de órdenes que hacen los clientes (es decir, cuántos clientes hicieron solo 1 pedido, cuántos hicieron 2, cuántos 3, y así sucesivamente...).
# 3. ¿Cuáles son los 20 principales productos que se piden con más frecuencia (muestra su identificación y nombre)?

# %% [markdown]
# ### [B1] Diferencia entre miércoles y sábados para  `'order_hour_of_day'`. Traza gráficos de barra para los dos días y describe las diferencias que veas.

# %% [markdown]
# 1. ¿Existe alguna diferencia entre las distribuciones `'order_hour_of_day'` de los miércoles y los sábados? Traza gráficos de barra de `'order_hour_of_day'` para ambos días en la misma figura y describe las diferencias que observes.

# %%
from matplotlib import pyplot as plt

# Filter orders for Wednesday (order_dow == 2)
wed_orders_by_hour = instacart_orders_s[instacart_orders_s['order_dow'] == 2].groupby('order_hour_of_day')['user_id'].nunique().sort_index()

# Filter orders for Saturday (order_dow == 6)
satur_orders_by_hour = instacart_orders_s[instacart_orders_s['order_dow'] == 6].groupby('order_hour_of_day')['user_id'].nunique().sort_index()

wed_orders_by_hour.plot(x='order_hour_of_day',
                        y=['wed_orders_by_hour'],
                        kind='bar',
                        title='Distribucion de usuarios S vs D',
                        xlabel='Numero de usuarios únicos',
                        ylabel='Population (millions)',
                        color='Grey')
satur_orders_by_hour.plot(x='order_hour_of_day',
                          y=['satur_orders_by_hour'],
                          kind='bar',
                          alpha=0.5)

# escribe tu código aquí
plt.legend(['wednesday', 'Saturday'])# escribe tu código aquí
plt.show()

# %%
from matplotlib import pyplot as plt

# Filter orders for Wednesday (order_dow == 2)
wed_orders_by_hour = instacart_orders_s[instacart_orders_s['order_dow'] == 2].groupby('order_hour_of_day')['user_id'].nunique().sort_index()

# Filter orders for Saturday (order_dow == 6)
satur_orders_by_hour = instacart_orders_s[instacart_orders_s['order_dow'] == 6].groupby('order_hour_of_day')['user_id'].nunique().sort_index()

wed_orders_by_hour.plot(x='order_hour_of_day',
                        y=['wed_orders_by_hour'],
                        kind='bar',
                        title='Distribucion de usuarios S vs D',
                        xlabel='Numero de usuarios únicos',
                        ylabel='Population (millions)',
                        color='Grey')
satur_orders_by_hour.plot(x='order_hour_of_day',
                          y=['satur_orders_by_hour'],
                          kind='bar',
                          alpha=0.5)

# escribe tu código aquí
plt.legend(['wednesday', 'Saturday'])# escribe tu código aquí
plt.show()

# %%
import matplotlib.pyplot as plt

# Filter orders for Wednesday (order_dow == 2)
wednesday_orders_by_hour = instacart_orders_s[instacart_orders_s['order_dow'] == 2].groupby('order_hour_of_day')['user_id'].nunique().sort_index()

# Filter orders for Saturday (order_dow == 6)
saturday_orders_by_hour = instacart_orders_s[instacart_orders_s['order_dow'] == 6].groupby('order_hour_of_day')['user_id'].nunique().sort_index()

# Plotting
plt.figure(figsize=(7, 4))
wednesday_orders_by_hour.plot(kind='bar', alpha=0.7, label='Miércoles', color='Grey')
saturday_orders_by_hour.plot(kind='bar', alpha=0.7, label='Sábado')

plt.title('Distribución de usuarios únicos que hacen pedidos por hora del día (Miércoles vs. Sábado)')
plt.xlabel('Hora del día')
plt.ylabel('Número de usuarios únicos')
plt.legend()
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
import matplotlib.pyplot as plt

# Filter orders for Wednesday (order_dow == 2)
wednesday_orders_by_hour = instacart_orders_s[instacart_orders_s['order_dow'] == 2].groupby('order_hour_of_day')['user_id'].nunique().sort_index()

# Filter orders for Saturday (order_dow == 6)
saturday_orders_by_hour = instacart_orders_s[instacart_orders_s['order_dow'] == 6].groupby('order_hour_of_day')['user_id'].nunique().sort_index()

# Plotting
plt.figure(figsize=(7, 4))
wednesday_orders_by_hour.plot(kind='bar', alpha=0.7, label='Miércoles', color='Grey')
saturday_orders_by_hour.plot(kind='bar', alpha=0.7, label='Sábado')

plt.title('Distribución de usuarios únicos que hacen pedidos por hora del día (Miércoles vs. Sábado)')
plt.xlabel('Hora del día')
plt.ylabel('Número de usuarios únicos')
plt.legend()
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Filter orders for Wednesday (order_dow == 2)
wednesday_orders_by_hour = instacart_orders_s[instacart_orders_s['order_dow'] == 2].groupby('order_hour_of_day')['user_id'].nunique().sort_index()

# Filter orders for Saturday (order_dow == 6)
saturday_orders_by_hour = instacart_orders_s[instacart_orders_s['order_dow'] == 6].groupby('order_hour_of_day')['user_id'].nunique().sort_index()

# Plotting
plt.figure(figsize=(10, 6))

bar_width = 0.35
index = np.arange(len(wednesday_orders_by_hour))

plt.bar(index - bar_width/2, wednesday_orders_by_hour, bar_width, alpha=0.7, label='Miércoles', color='steelblue')
plt.bar(index + bar_width/2, saturday_orders_by_hour, bar_width, alpha=0.7, label='Sábado', color='lightgrey')

plt.title('Distribución de usuarios únicos que hacen pedidos por hora del día (Miércoles vs. Sábado)')
plt.xlabel('Hora del día')
plt.ylabel('Número de usuarios únicos')
plt.legend()
plt.xticks(index, wednesday_orders_by_hour.index, rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Filtrar pedidos para el miércoles (order_dow == 2)
wednesday_orders_by_hour_alt = instacart_orders_s[instacart_orders_s['order_dow'] == 2].groupby('order_hour_of_day')['user_id'].nunique().sort_index()

# Filtrar pedidos para el sábado (order_dow == 6)
saturday_orders_by_hour_alt = instacart_orders_s[instacart_orders_s['order_dow'] == 6].groupby('order_hour_of_day')['user_id'].nunique().sort_index()

# Asegurarse de que ambos Series tengan el mismo índice (horas de 0 a 23)
# Esto es importante si algún día no tuviera pedidos en alguna hora, aunque en este caso ya están completos.
hours = np.arange(24)
wednesday_orders_by_hour_alt = wednesday_orders_by_hour_alt.reindex(hours, fill_value=0)
saturday_orders_by_hour_alt = saturday_orders_by_hour_alt.reindex(hours, fill_value=0)

# Configuración de la gráfica
fig, ax = plt.subplots(figsize=(12, 7))

bar_width = 0.35 # Ancho de cada barra

# Posiciones de las barras en el eje X
# Para el miércoles, las barras estarán un poco a la izquierda de la marca de la hora
# Para el sábado, las barras estarán un poco a la derecha de la marca de la hora
r1 = np.arange(len(hours))
r2 = [x + bar_width for x in r1]

# Crear las barras para el miércoles
ax.bar(r1, wednesday_orders_by_hour_alt, color='steelblue', width=bar_width, edgecolor='grey', label='Miércoles', alpha=0.7)

# Crear las barras para el sábado
ax.bar(r2, saturday_orders_by_hour_alt, color='lightgrey', width=bar_width, edgecolor='grey', label='Sábado', alpha=0.7)

# Añadir título, etiquetas y leyendas
ax.set_xlabel('Hora del día', fontweight='bold')
ax.set_ylabel('Número de usuarios únicos', fontweight='bold')
ax.set_title('Distribución de usuarios únicos que hacen pedidos por hora del día (Miércoles vs. Sábado)', fontweight='bold')
ax.set_xticks([r + bar_width / 2 for r in range(len(hours))]) # Centrar las etiquetas de las horas
ax.set_xticklabels(hours, rotation=0)
ax.legend()
ax.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# Bien hecho, muy bien al realizar el gráfico con las barras una junta a la otra, esto permite una comparación directa entre los días.
#
# Recuerda dejar un solo gráfico, no es bueno repetirlo tantas veces.
#
# </div>

# %% [markdown]
# Escribe aquí tus conclusiones Se muestran graficos que evidencia la distribución de usuarios que hacen pedidos por hora del día, contrastando el día Miercoles Vs Sabado, el Sabado se muestra un día más destacado respecto a los pedidos del día Miercoles. Tambien es posible visualizar una distribucion similar de (9 am a 3 pm) con una mayor cantidad de compras y un horario por las mañanas ( 5am a 8 am) y un horario por las tardes de (4 am a 10 pm)con una menor acantidad de compras, tambien es posible visualizar un horario nocturno bastante estatico y con muy pocas o núlos pedidos que corresponde a los horarios de (11 pm a 5 am).

# %% [markdown]
# ### [B2] ¿Cuál es la distribución para el número de pedidos por cliente?

# %% [markdown]
# 2. Grafica la distribución para el número de órdenes que hacen los clientes (es decir, cuántos clientes hicieron solo 1 pedido, cuántos hicieron 2, cuántos 3, y así sucesivamente...).

# %%
# Calcula el número total de órdenes por cada cliente
orders_per_customer_a = instacart_orders_s.groupby('user_id')['order_id'].count()

# Obtiene la distribución del número de órdenes
order_counts_a = orders_per_customer_a.value_counts().sort_index()

order_counts_a.plot(kind='bar',
                    title='Distribucion de pedidos por tiempo de espera',
                    xlabel='Tiempo de espera',
                    ylabel='Número de Pedidos',
                    figsize=(15, 7))
plt.show()

# %%
# Calcula el número total de órdenes por cada cliente
orders_per_customerq = instacart_orders_s.groupby('user_id')['order_id'].count()

# Obtiene la distribución del número de órdenes
order_countsq = orders_per_customerq.value_counts().sort_index()

# Crea el gráfico de barras
plt.figure(figsize=(15, 7))
order_countsq.plot(kind='bar')
plt.title('Distribución del número de órdenes por cliente')
plt.xlabel('Número de órdenes realizadas por el cliente')
plt.ylabel('Número de clientes')
plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor     v2     </b> <a class="tocSkip"></a>
#
#
# Bien hecho, corregido!
#
#
# </div>

# %% [markdown]
# # Ejercicio 3 a Revisar
# <div class='alert alert-block alert-info'>
# <b>Respuesta estudiante. En esta parte se trabajo el ejercicio 3 que se menciona unas celdas despues </b> <a class='tocSkip'></a>
# </div>

# %% [markdown]
# <div class='alert alert-block alert-info'>
# <b>En estas graficas realizadas observamos la distribucion del numero de ordenes unicas por cliente, graficando en el eje x el número de ordenes realizadas por cliente contra el eje y que grafica el numero de clientes, a diferencia de los ejercicios realizados en celdas pposteriores si podemos observar una disminución en el números de pedidos. Y observamos que las ordenes realizadas por cliente van de 1 a 20 </b> <a class='tocSkip'></a>
# </div>

# %%
# Calcula el número total de órdenes por cada cliente
orders_per_customer = instacart_orders_s.groupby('user_id')['order_number'].max()

# Obtiene la distribución del número de órdenes
order_counts = orders_per_customer.value_counts().sort_index()

order_counts.plot(kind='bar',
                  title='Distribucion de pedidos por tiempo de espera',
                  xlabel='Tiempo de espera',
                  ylabel='Número de Pedidos',
                  figsize=(15, 7))
plt.show()

# %%
# Calcula el número total de órdenes por cada cliente
orders_per_customer = instacart_orders_s.groupby('user_id')['order_number'].max()

# Obtiene la distribución del número de órdenes
order_counts = orders_per_customer.value_counts().sort_index()

# Crea el gráfico de barras
plt.figure(figsize=(15, 7))
order_counts.plot(kind='bar')
plt.title('Distribución del número de órdenes por cliente')
plt.xlabel('Número de órdenes realizadas por el cliente')
plt.ylabel('Número de clientes')
plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
# En estos graficos podemos visualizar la distribucion de pedidos por cliente en el eje x visualizamos en numero de pedidos y en el eje y visualizamos el numero de clientes que han realizado pedidos como podemos visualizar que de los cleintes la mayoria ha realizado 4 pedidos con 12000 clientes aproximadamente mientras que quienes marcando un rando de 3 a 1 pedidos si una gran poblacion pero en orden descendente al igual que de 5 a 10 en orden descendente respecto a la cantidad de pedidos. es posible observar ese patron.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# El cálculo es incorrecto puesto que estás usando el número de orden (`order_number`) como la cantidad de ordenes que ha hecho el usuario, pero esto no necesariamente es así. Para obtener la cantidad correcta, se debe agrupar por usuario y contar la cantidad de pedidos únicos en la data que disponemos. Verás que el resultado es diferente.
#
# El id del número de orden de cada pedido no necesariamente representa la cantidad de pedidos realizados por el usuario, puede ser un número grande y haber hecho pocos pedidos o viceversa. Tal vez podría ser el número de pedidos que ha creado, pero no necesariamente que ha concretado, o un número aleatorio.
#
# </div>

# %% [markdown]
# # Ejercicio 3 a Revisar
# <div class='alert alert-block alert-info'>
# <b>Respuesta estudiante. Se trabajara en un apartado anterior para que lo puedan revisar  </b> <a class='tocSkip'></a>
# </div>

# %% [markdown]
# ### [B3] ¿Cuáles son los 20 productos más populares (muestra su ID y nombre)?

# %% [markdown]
# 3. ¿Cuáles son los 20 principales productos que se piden con más frecuencia (muestra su identificación y nombre)?

# %%
import matplotlib.pyplot as plt

# Combina los DataFrames order_products_s y products_s para obtener los nombres de los productos
merged_products = pd.merge(order_products_s, products_s, on='product_id', how='left')

# Cuenta la frecuencia de cada producto
product_counts = merged_products['product_id'].value_counts()

# Obtiene los 20 productos más frecuentes y sus recuentos
top_20_products_df = product_counts.head(20).reset_index()
top_20_products_df.columns = ['product_id', 'count'] # Renombra las columnas

# Fusiona con products_s para obtener los nombres de los productos
top_20_products_df = pd.merge(top_20_products_df, products_s[['product_id', 'product_name']], on='product_id', how='left')

# Muestra la identificación y el nombre de los 20 productos principales
print("Los 20 principales productos que se piden con más frecuencia:")
display(top_20_products_df[['product_id', 'product_name', 'count']])
# Out:
# Los 20 principales productos que se piden con más frecuencia:
#     product_id              product_name  count
# 0        24852                    Banana  66050
# 1        13176    Bag of Organic Bananas  53297
# 2        21137      Organic Strawberries  37039
# 3        21903      Organic Baby Spinach  33971
# 4        47209      Organic Hass Avocado  29773
# 5        47766           Organic Avocado  24689
# 6        47626               Large Lemon  21495
# 7        16797              Strawberries  20018
# 8        26209                     Limes  19690
# 9        27845        Organic Whole Milk  19600
# 10       27966       Organic Raspberries  19197
# 11       22935      Organic Yellow Onion  15898
# 12       24964            Organic Garlic  15292
# 13       45007          Organic Zucchini  14584
# 14       39275       Organic Blueberries  13879
# 15       49683            Cucumber Kirby  13675
# 16       28204        Organic Fuji Apple  12544
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario de Revisor          </b> <a class="tocSkip"></a>
#
# La celda anterior tiene error porque `product_id` no existe como columna, por favor revisalo si es que necesitas ejecutar la celda o eliminala si no aporta ningún resultado.
#
#
#
# </div>

# %% [markdown]
# <div class='alert alert-block alert-info'>
# <b>Respuesta estudiante. Hola tal vez esta confuso el codigo pero me parece que funciona, tal vez product_id no se encuentre en el DataFrame products pero si se encuentra en el DataFrame order_products_s pero igual si aún es un inconveniente si me lo indica elimino la celda </b> <a class='tocSkip'></a>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor    v2      </b> <a class="tocSkip"></a>
#
#
# Muy bien, corregido, vemos el nombre y la cantidad de veces que fue pedido.
#
#
# </div>

# %%
import matplotlib.pyplot as plt

# Combinar los DataFrames order_products_s y products_s para obtener los nombres de los productos
merged_products = pd.merge(order_products_s, products_s, on='product_id', how='left')

# Cuenta la frecuencia de cada producto
product_counts = merged_products['product_id'].value_counts()

# Obtiene los 20 productos más frecuentes y sus nombres
# Crea un DataFrame para los 20 productos principales con sus nombres y recuentos
top_20_products_df = product_counts.head(20).reset_index()
top_20_products_df.columns = ['product_id', 'count'] # Renombra las columnas
top_20_products_df = pd.merge(top_20_products_df, products_s[['product_id', 'product_name']], on='product_id', how='left')

# Muestra la identificación y el nombre de los 20 productos principales
print("Los 20 principales productos que se piden con más frecuencia:")
display(top_20_products_df[['product_id', 'product_name', 'count']])

top_20_products_df.plot(x='product_name',
                        y='count',
                        kind='bar',
                        title='Top 20 Productos Más Frecuentes',
                        xlabel='Nombre del Producto',
                        ylabel='Número de Pedidos',
                        alpha=0.5,
                        figsize=(15,7))
# escribe tu código aquí
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()






# el gráfico de barras para los 20 productos más frecuentes
# Out:
# Los 20 principales productos que se piden con más frecuencia:
#     product_id              product_name  count
# 0        24852                    Banana  66050
# 1        13176    Bag of Organic Bananas  53297
# 2        21137      Organic Strawberries  37039
# 3        21903      Organic Baby Spinach  33971
# 4        47209      Organic Hass Avocado  29773
# 5        47766           Organic Avocado  24689
# 6        47626               Large Lemon  21495
# 7        16797              Strawberries  20018
# 8        26209                     Limes  19690
# 9        27845        Organic Whole Milk  19600
# 10       27966       Organic Raspberries  19197
# 11       22935      Organic Yellow Onion  15898
# 12       24964            Organic Garlic  15292
# 13       45007          Organic Zucchini  14584
# 14       39275       Organic Blueberries  13879
# 15       49683            Cucumber Kirby  13675
# 16       28204        Organic Fuji Apple  12544
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Combina los DataFrames order_products_s y products_s para obtener los nombres de los productos
merged_products = pd.merge(order_products_s, products_s, on='product_id', how='left')

# Cuenta la frecuencia de cada producto
product_counts = merged_products['product_id'].value_counts()

# Obtiene los 20 productos más frecuentes y sus nombres
# Crea un DataFrame para los 20 productos principales con sus nombres y recuentos
top_20_products_df = product_counts.head(20).reset_index()
top_20_products_df.columns = ['product_id', 'count'] # Renombra las columnas
top_20_products_df = pd.merge(top_20_products_df, products_s[['product_id', 'product_name']], on='product_id', how='left')

# Muestra la identificación y el nombre de los 20 productos principales
print("Los 20 principales productos que se piden con más frecuencia:")
display(top_20_products_df[['product_id', 'product_name', 'count']])

# Crea el gráfico de barras para los 20 productos más frecuentes
plt.figure(figsize=(12, 7))
sns.barplot(x='product_name', y='count', data=top_20_products_df, palette='viridis')
plt.title('Top 20 Productos Más Frecuentes')
plt.xlabel('Nombre del Producto')
plt.ylabel('Número de Pedidos')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# Los 20 principales productos que se piden con más frecuencia:
#     product_id              product_name  count
# 0        24852                    Banana  66050
# 1        13176    Bag of Organic Bananas  53297
# 2        21137      Organic Strawberries  37039
# 3        21903      Organic Baby Spinach  33971
# 4        47209      Organic Hass Avocado  29773
# 5        47766           Organic Avocado  24689
# 6        47626               Large Lemon  21495
# 7        16797              Strawberries  20018
# 8        26209                     Limes  19690
# 9        27845        Organic Whole Milk  19600
# 10       27966       Organic Raspberries  19197
# 11       22935      Organic Yellow Onion  15898
# 12       24964            Organic Garlic  15292
# 13       45007          Organic Zucchini  14584
# 14       39275       Organic Blueberries  13879
# 15       49683            Cucumber Kirby  13675
# 16       28204        Organic Fuji Apple  12544
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# Correcto,  se ve que predominan los productos orgánicos y de uso diario
#
# </div>

# %% [markdown]
# Escribe aquí tus conclusiones
# En esta grafica de barras se muestra el top de los 20 productos mas frecuentes, en el eje de las x podemos visializar a los 20 productos mas frecuentes, en el eje y el numero de pedidos donde observamos y mencionamos solo algunosde ellos como el producto más consumido son las bananas con 30000 pedidos seguido de las fresas con  poco menos de 25000 pedidos y en la lista de los más frecuentes pero en ultimo lugar respecto a esos 20 productos la uva sin semilla roja con aproximadamente 5000 pedidos.

# %% [markdown]
# # [C] Difícil (deben completarse todos para aprobar)
#
# 1. ¿Cuántos artículos suelen comprar las personas en un pedido? ¿Cómo es la distribución?
# 2. ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?
# 3. Para cada producto, ¿cuál es la tasa de repetición del pedido (número de repeticiones de pedido/total de pedidos?
# 4. Para cada cliente, ¿qué proporción de los productos que pidió ya los había pedido? Calcula la tasa de repetición de pedido para cada usuario en lugar de para cada producto.
# 5. ¿Cuáles son los 20 principales artículos que la gente pone primero en sus carritos (muestra las IDs de los productos, sus nombres, y el número de veces en que fueron el primer artículo en añadirse al carrito)?

# %% [markdown]
# ### [C1] ¿Cuántos artículos compran normalmente las personas en un pedido? ¿Cómo es la distribución?

# %% [markdown]
# 1. ¿Cuántos artículos suelen comprar las personas en un pedido? ¿Cómo es la distribución?

# %%
# Calcula el número de artículos por pedido
items_per_order = order_products_s.groupby('order_id')['product_id'].count()

# Muestra las primeras filas de la distribución
print("Número de artículos por pedido (primeras 5 filas):")
display(items_per_order.head())

# Calcula la distribución de cuántos pedidos tienen X número de artículos
item_count_distribution = items_per_order.value_counts().sort_index()

print("\nDistribución del número de artículos por pedido:")
display(item_count_distribution.head())
# Out:
# Número de artículos por pedido (primeras 5 filas):
# order_id
# 4     13
# 9     15
# 11     5
# 19     3
# 20     8
# Name: product_id, dtype: int64
# Distribución del número de artículos por pedido:
# product_id
# 1    21847
# 2    26292
# 3    29046
# 4    31054
# 5    31923
# Name: count, dtype: int64

# %%
item_count_distribution.plot(kind='bar',
                             title='Distribución del Número de Artículos por Pedido',
                             xlabel='Número de Artículos en el Pedido',
                             ylabel='Número de Pedidos',
                             figsize=(15, 7),
                             alpha=0.7)
# escribe tu código aquí
plt.tight_layout()# escribe tu código aquí
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 7))
item_count_distribution.plot(kind='bar')
plt.title('Distribución del Número de Artículos por Pedido')
plt.xlabel('Número de Artículos en el Pedido')
plt.ylabel('Número de Pedidos')
plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor      </b> <a class="tocSkip"></a>
#
# Muy bien con el gráfico, está correcto. Vemos que hay una distribución concentrada en los primeros valores, pero luego cae muy rápido
#
#
# </div>

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Conclusiones sobre el número de artículos por pedido y su distribución
# El gráfico de barras muestra la frecuencia de los pedidos según la cantidad de artículos que contienen. Podemos observar que la mayoría de los pedidos tienen un número relativamente bajo de artículos, con un pico en un valor específico y luego una disminución gradual a medida que aumenta la cantidad de artículos. Esto es típico en las compras de comestibles, donde los clientes suelen comprar algunos artículos esenciales o reponer existencias con mayor frecuencia que realizar grandes pedidos con muchísimos artículos.

# %% [markdown]
# ### [C2] ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?

# %% [markdown]
# 2. ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?

# %%
import pandas as pd

# Comentario de RevisorEsta parte es similar a B3, Pero
# primero debes obtener solamente los artículos que se reordenaron.
# Para ello, primero filtra con order_products_s[order_products_s['reordered']==1]

art_reord = order_products_s[order_products_s['reordered']==1]

# y luego, sobre ese resultdo, agrupa por product_id y cuenta cuantas veces se ha pedido,

veces_pedido_cont = art_reord.groupby('product_id')['reordered'].count()

# Convert the Series to a DataFrame and reset index, naming the count column appropriately
reordered_counts_df = veces_pedido_cont.reset_index(name='reorder_count')

# Unir con el DataFrame de productos para obtener los nombres de los productos
merged_reordered = pd.merge(reordered_counts_df, products_s[['product_id', 'product_name']], on='product_id', how='left')

# Ordenar por el número de reordenamientos y seleccionar los 20 principales
top_20_reordered_a = merged_reordered.sort_values(by='reorder_count', ascending=False).head(20)


# Mostrar el resultado
print("Los 20 principales productos que se reordenan con mayor frecuencia:")
display(top_20_reordered_a[['product_id', 'product_name', 'reorder_count']])

# imprimir resultado

# Mostrar el resultado (redundant with the previous display, but keeping for user's intent)
print("Los 20 principales productos que se reordenan con mayor frecuencia:" )
print("Product_id  y Nombre" )
display(top_20_reordered_a[['product_id', 'product_name']])

print(top_20_reordered_a)

top_20_reordered_a.plot(x='product_id',
                        y='reorder_count',
                        kind='bar',
                        title='Top 20 Productos Más Frecuentes',
                        xlabel='Nombre del Producto',
                        ylabel='Número de Pedidos',
                        alpha=0.5,
                        figsize=(15,7))
# escribe tu código aquí
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# Los 20 principales productos que se reordenan con mayor frecuencia:
#        product_id              product_name  reorder_count
# 18104       24852                    Banana          55763
# 9528        13176    Bag of Organic Bananas          44450
# 15368       21137      Organic Strawberries          28639
# 15936       21903      Organic Baby Spinach          26233
# 34407       47209      Organic Hass Avocado          23629
# 34828       47766           Organic Avocado          18743
# 20285       27845        Organic Whole Milk          16251
# 34725       47626               Large Lemon          15044
# 20375       27966       Organic Raspberries          14748
# 12193       16797              Strawberries          13945
# 19088       26209                     Limes          13327
# 16700       22935      Organic Yellow Onion          11145
# 18186       24964            Organic Garlic          10411
# 32792       45007          Organic Zucchini          10076
# ...

# %%
import pandas as pd

# Filtrar solo los artículos que se reordenaron
reordered_products = order_products_s[order_products_s['reordered'] == 1]

# Agrupar por product_id y contar la frecuencia de reordenamiento
reordered_counts = reordered_products['product_id'].value_counts().reset_index()
reordered_counts.columns = ['product_id', 'reorder_count']

# Unir con el DataFrame de productos para obtener los nombres de los productos
top_20_reordered = pd.merge(reordered_counts, products_s[['product_id', 'product_name']], on='product_id', how='left')

# Ordenar por el número de reordenamientos y seleccionar los 20 principales
top_20_reordered = top_20_reordered.sort_values(by='reorder_count', ascending=False).head(20)

# Mostrar el resultado
print("Los 20 principales productos que se reordenan con mayor frecuencia:")
display(top_20_reordered[['product_id', 'product_name', 'reorder_count']])


top_20_reordered.plot(x='product_id',
                      y='reorder_count',
                      kind='bar',
                      title='Top 20 Productos Más Frecuentes',
                      xlabel='Nombre del Producto',
                      ylabel='Número de Pedidos',
                      alpha=0.5,
                      figsize=(15,7))
# escribe tu código aquí
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# Los 20 principales productos que se reordenan con mayor frecuencia:
#     product_id              product_name  reorder_count
# 0        24852                    Banana          55763
# 1        13176    Bag of Organic Bananas          44450
# 2        21137      Organic Strawberries          28639
# 3        21903      Organic Baby Spinach          26233
# 4        47209      Organic Hass Avocado          23629
# 5        47766           Organic Avocado          18743
# 6        27845        Organic Whole Milk          16251
# 7        47626               Large Lemon          15044
# 8        27966       Organic Raspberries          14748
# 9        16797              Strawberries          13945
# 10       26209                     Limes          13327
# 11       22935      Organic Yellow Onion          11145
# 12       24964            Organic Garlic          10411
# 13       45007          Organic Zucchini          10076
# 14       49683            Cucumber Kirby           9538
# ...

# %% [markdown]
# <div class='alert alert-block alert-info'>
# <b>Respuesta estudiante.  Ejercicio a revisar #5 </b> <a class='tocSkip'></a>
# </div>
#  Podemos observar una dismunicion en el numero de pedidos en la graficación a diferencia de la conclusión anterior pero basicamente se observa el mismo patron con con ligeras variaciones en los elementos pero se sigue conservando la misma conclusion que de que los consumidores realizan pedidos de elementos organicos en su mayoria.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor      v2    </b> <a class="tocSkip"></a>
#
#
# Muy bien, corregido, ahora se muestra el top 20 más frecuentes de los más reordenados.
#
#
# </div>

# %%
# Comentario de RevisorEsta parte es similar a B3, Pero
# primero debes obtener solamente los artículos que se reordenaron.
# Para ello, primero filtra con order_products_s[order_products_s['reordered']==1]

art_reord = order_products_s[order_products_s['reordered']==1]

# y luego, sobre ese resultdo, agrupa por product_id y cuenta cuantas veces se ha pedido,

veces_pedido = art_reord.groupby('product_id')['reordered'].count()

# luego ordena las filas en base a ese conteo

ord_filas_en_base_a_conteo = veces_pedido.sort_values(ascending=False)

# y selecciona el top 20.

top_20 = ord_filas_en_base_a_conteo.head(20)

# imprimir resultado

print(top_20)
# Out:
# product_id
# 24852    55763
# 13176    44450
# 21137    28639
# 21903    26233
# 47209    23629
# 47766    18743
# 27845    16251
# 47626    15044
# 27966    14748
# 16797    13945
# 26209    13327
# 22935    11145
# 24964    10411
# 45007    10076
# 49683     9538
# 28204     8989
# 8277      8836
# 39275     8799
# 5876      8412
# 49235     8389
# Name: reordered, dtype: int64

# %%
import matplotlib.pyplot as plt

# Combinar los DataFrames order_products_s y products_s para obtener los nombres de los productos
merged_products = pd.merge(order_products_s, products_s, on='product_id', how='left')

# Cuenta la frecuencia de cada producto
product_counts = merged_products['product_id'].value_counts()

# Obtiene los 20 productos más frecuentes y sus nombres
# Crea un DataFrame para los 20 productos principales con sus nombres y recuentos
top_20_products_df = product_counts.head(20).reset_index()
top_20_products_df.columns = ['product_id', 'count'] # Renombra las columnas
top_20_products_df = pd.merge(top_20_products_df, products_s[['product_id', 'product_name']], on='product_id', how='left')

# Muestra la identificación y el nombre de los 20 productos principales
print("Los 20 principales productos que se piden con más frecuencia:")
display(top_20_products_df[['product_id', 'product_name', 'count']])

top_20_products_df.plot(x='product_id',
                        y='count',
                        kind='bar',
                        title='Top 20 Productos Más Frecuentes',
                        xlabel='Nombre del Producto',
                        ylabel='Número de Pedidos',
                        alpha=0.5,
                        figsize=(15,7))
# escribe tu código aquí
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()






# el gráfico de barras para los 20 productos más frecuentes
# Out:
# Los 20 principales productos que se piden con más frecuencia:
#     product_id              product_name  count
# 0        24852                    Banana  66050
# 1        13176    Bag of Organic Bananas  53297
# 2        21137      Organic Strawberries  37039
# 3        21903      Organic Baby Spinach  33971
# 4        47209      Organic Hass Avocado  29773
# 5        47766           Organic Avocado  24689
# 6        47626               Large Lemon  21495
# 7        16797              Strawberries  20018
# 8        26209                     Limes  19690
# 9        27845        Organic Whole Milk  19600
# 10       27966       Organic Raspberries  19197
# 11       22935      Organic Yellow Onion  15898
# 12       24964            Organic Garlic  15292
# 13       45007          Organic Zucchini  14584
# 14       39275       Organic Blueberries  13879
# 15       49683            Cucumber Kirby  13675
# 16       28204        Organic Fuji Apple  12544
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Combina los DataFrames order_products_s y products_s para obtener los nombres de los productos
merged_products = pd.merge(order_products_s, products_s, on='product_id', how='left')

# Cuenta la frecuencia de cada producto
product_counts = merged_products['product_id'].value_counts()

# Obtiene los 20 productos más frecuentes y sus nombres
# DataFrame para los 20 productos principales con sus nombres y recuentos
top_20_products_df = product_counts.head(20).reset_index()
top_20_products_df.columns = ['product_id', 'count'] # Renombra las columnas
top_20_products_df = pd.merge(top_20_products_df, products_s[['product_id', 'product_name']], on='product_id', how='left')

# Muestrar la identificación y el nombre de los 20 productos principales
print("Los 20 principales productos que se piden con más frecuencia:")
display(top_20_products_df[['product_id', 'product_name', 'count']])

# Crear el gráfico de barras para los 20 productos más frecuentes
plt.figure(figsize=(12, 7))
sns.barplot(x='product_id', y='count', data=top_20_products_df, palette='crest')
plt.title('Top 20 Productos Más Frecuentes')
plt.xlabel('Nombre del Producto')
plt.ylabel('Número de Pedidos')
plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# Los 20 principales productos que se piden con más frecuencia:
#     product_id              product_name  count
# 0        24852                    Banana  66050
# 1        13176    Bag of Organic Bananas  53297
# 2        21137      Organic Strawberries  37039
# 3        21903      Organic Baby Spinach  33971
# 4        47209      Organic Hass Avocado  29773
# 5        47766           Organic Avocado  24689
# 6        47626               Large Lemon  21495
# 7        16797              Strawberries  20018
# 8        26209                     Limes  19690
# 9        27845        Organic Whole Milk  19600
# 10       27966       Organic Raspberries  19197
# 11       22935      Organic Yellow Onion  15898
# 12       24964            Organic Garlic  15292
# 13       45007          Organic Zucchini  14584
# 14       39275       Organic Blueberries  13879
# 15       49683            Cucumber Kirby  13675
# 16       28204        Organic Fuji Apple  12544
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Combina los DataFrames order_products_s y products_s para obtener los nombres de los productos
merged_products = pd.merge(order_products_s, products_s, on='product_id', how='left')

# Cuenta la frecuencia de cada producto
product_counts = merged_products['product_id'].value_counts()

# Obtiene los 20 productos más frecuentes y sus nombres
# Crea un DataFrame para los 20 productos principales con sus nombres y recuentos
top_20_products_df = product_counts.head(20).reset_index()
top_20_products_df.columns = ['product_id', 'count'] # Renombra las columnas
top_20_products_df = pd.merge(top_20_products_df, products_s[['product_id', 'product_name']], on='product_id', how='left')

# Muestra la identificación y el nombre de los 20 productos principales
print("Los 20 principales productos que se piden con más frecuencia:")
display(top_20_products_df[['product_id', 'product_name', 'count']])

# Crea el gráfico de barras para los 20 productos más frecuentes
plt.figure(figsize=(12, 7))
sns.barplot(x='product_name', y='count', data=top_20_products_df, palette='mako')
plt.title('Top 20 Productos Más Frecuentes')
plt.xlabel('Nombre del Producto')
plt.ylabel('Número de Pedidos')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# Los 20 principales productos que se piden con más frecuencia:
#     product_id              product_name  count
# 0        24852                    Banana  66050
# 1        13176    Bag of Organic Bananas  53297
# 2        21137      Organic Strawberries  37039
# 3        21903      Organic Baby Spinach  33971
# 4        47209      Organic Hass Avocado  29773
# 5        47766           Organic Avocado  24689
# 6        47626               Large Lemon  21495
# 7        16797              Strawberries  20018
# 8        26209                     Limes  19690
# 9        27845        Organic Whole Milk  19600
# 10       27966       Organic Raspberries  19197
# 11       22935      Organic Yellow Onion  15898
# 12       24964            Organic Garlic  15292
# 13       45007          Organic Zucchini  14584
# 14       39275       Organic Blueberries  13879
# 15       49683            Cucumber Kirby  13675
# 16       28204        Organic Fuji Apple  12544
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario de Revisor              </b><a class="tocSkip"></a>
#
#
# Esta parte es similar a B3, pero primero debes obtener solamente los artículos que se reordenaron. Para ello, primero filtra con `order_products_s[order_products_s['reordered']==1]` y luego, sobre ese resultdo, agrupa por product_id y cuenta cuantas veces se ha pedido, luego ordena las filas en base a ese conteo y selecciona el top 20.
#
#
# </div>

# %% [markdown]
# Escribe aquí tus conclusiones
#
# El análisis de los 20 productos más frecuentemente pedidos revela una clara preferencia por artículos frescos y orgánicos. Productos básicos como el 'Banana' y la 'Bag of Organic Bananas' lideran la lista con una diferencia significativa, seguidos de cerca por 'Organic Strawberries', 'Organic Baby Spinach' y 'Organic Hass Avocado'. Esto sugiere que los clientes utilizan la plataforma Instacart principalmente para la compra de alimentos esenciales y saludables. La presencia de varias opciones orgánicas en los primeros puestos indica una fuerte demanda por productos de este tipo. Identificar estos productos clave es fundamental para la gestión de inventario, estrategias de marketing y para entender los hábitos de consumo de los clientes.

# %% [markdown]
# ### [C3] Para cada producto, ¿cuál es la proporción de las veces que se pide y que se vuelve a pedir?

# %% [markdown]
# 3. Para cada producto, ¿cuál es la tasa de repetición del pedido (número de repeticiones de pedido/total de pedidos?

# %%
# Calcula el total de pedidos y reordenados para cada producto
product_reorder_counts = order_products_s.groupby('product_id')['reordered'].agg(['count', 'sum']).reset_index()
product_reorder_counts.columns = ['product_id', 'total_orders', 'total_reorders']

# Calcula la tasa de repetición de pedido
product_reorder_counts['reorder_ratio'] = product_reorder_counts['total_reorders'] / product_reorder_counts['total_orders']

# Fusiona con el DataFrame de productos para obtener los nombres de los productos
product_reorder_ratio_df = pd.merge(product_reorder_counts, products_s[['product_id', 'product_name']], on='product_id', how='left')

# Muestra los productos con la tasa de repetición de pedido más alta
print("Productos con las tasas de repetición de pedido más altas (primeras 20 filas):")
display(product_reorder_ratio_df.sort_values(by='reorder_ratio', ascending=False).head(20))
# Out:
# Productos con las tasas de repetición de pedido más altas (primeras 20 filas):
#        product_id  total_orders  total_reorders  reorder_ratio  \
# 28108       30644             2               2            1.0
# 7340         8054             1               1            1.0
# 28114       30650             2               2            1.0
# 41002       44747             1               1            1.0
# 40998       44743             2               2            1.0
# 32921       35897             1               1            1.0
# 32861       35834             2               2            1.0
# 2684         2939             7               7            1.0
# 20357       22209             2               2            1.0
# 20361       22213             2               2            1.0
# 20343       22194             1               1            1.0
# 20350       22201             1               1            1.0
# 2712         2970             1               1            1.0
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# Muy bien, correcto. También se puede usar la media de `reordered` para este cálculo.
#
# </div>

# %%
# Calcula el total de pedidos y reordenados para cada producto
product_reorder_counts = order_products_s.groupby('product_id')['reordered'].agg(['count', 'sum']).reset_index()
product_reorder_counts.columns = ['product_id', 'total_orders', 'total_reorders']

# Calcula la tasa de repetición de pedido
product_reorder_counts['reorder_ratio'] = product_reorder_counts['total_reorders'] / product_reorder_counts['total_orders']

# Fusiona con el DataFrame de productos para obtener los nombres de los productos
product_reorder_ratio_df = pd.merge(product_reorder_counts, products_s[['product_id', 'product_name']], on='product_id', how='left')

# Muestra los productos con la tasa de repetición de pedido más alta
print("Productos con las tasas de repetición de pedido más altas:")
display(product_reorder_ratio_df.sort_values(by='reorder_ratio', ascending=False).head(20))
# Out:
# Productos con las tasas de repetición de pedido más altas:
#        product_id  total_orders  total_reorders  reorder_ratio  \
# 28108       30644             2               2            1.0
# 7340         8054             1               1            1.0
# 28114       30650             2               2            1.0
# 41002       44747             1               1            1.0
# 40998       44743             2               2            1.0
# 32921       35897             1               1            1.0
# 32861       35834             2               2            1.0
# 2684         2939             7               7            1.0
# 20357       22209             2               2            1.0
# 20361       22213             2               2            1.0
# 20343       22194             1               1            1.0
# 20350       22201             1               1            1.0
# 2712         2970             1               1            1.0
# ...

# %%
veces_repetido = order_products_s.groupby('product_id')['reordered'].agg(['count', 'sum']).reset_index()
veces_repetido.columns = ['product_id', 'total_orders', 'total_reorders']
veces_repetido['reorder_ratio'] = veces_repetido['total_reorders'] / veces_repetido['total_orders']

print("Productos con la tasa de repetición de pedido más alta:")
display(veces_repetido.sort_values(by='reorder_ratio', ascending=False).head(20))
# Out:
# Productos con la tasa de repetición de pedido más alta:
#        product_id  total_orders  total_reorders  reorder_ratio
# 28108       30644             2               2            1.0
# 7340         8054             1               1            1.0
# 28114       30650             2               2            1.0
# 41002       44747             1               1            1.0
# 40998       44743             2               2            1.0
# 32921       35897             1               1            1.0
# 32861       35834             2               2            1.0
# 2684         2939             7               7            1.0
# 20357       22209             2               2            1.0
# 20361       22213             2               2            1.0
# 20343       22194             1               1            1.0
# 20350       22201             1               1            1.0
# 2712         2970             1               1            1.0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Selecciona los top 20 productos por tasa de repetición de pedido
top_20_reordered_products = product_reorder_ratio_df.sort_values(by='reorder_ratio', ascending=False).head(20)

plt.figure(figsize=(14, 8))
sns.barplot(x='product_name', y='reorder_ratio', data=top_20_reordered_products, palette='mako')
plt.title('Top 20 Productos con Mayor Tasa de Repetición de Pedido')
plt.xlabel('Nombre del Producto')
plt.ylabel('Tasa de Repetición de Pedido')
plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\hilary\AppData\Local\Temp\ipykernel_27988\2982915791.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='product_name', y='reorder_ratio', data=top_20_reordered_products, palette='mako')

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# Muy bien, correcto el gráfico. Vemos muchos productos con tasa 1, aunque probablemente hay productos que solo se han pedidos 2 veces, la segunda vez es un reorden, y por eso tienen 100% de reorden. Para mostrar la generalidad de los productos, te recomiendo realizar un histograma.
#
# </div>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Selecciona los top 20 productos por el total de órdenes
top_20_total_orders = product_reorder_ratio_df.sort_values(by='total_orders', ascending=False).head(20)

plt.figure(figsize=(14, 8))
sns.barplot(x='product_name', y='total_orders', data=top_20_total_orders, palette='mako')
plt.title('Top 20 Productos con Mayor Cantidad de Órdenes')
plt.xlabel('Nombre del Producto')
plt.ylabel('Total de Órdenes')
plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\hilary\AppData\Local\Temp\ipykernel_27988\3497092104.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='product_name', y='total_orders', data=top_20_total_orders, palette='mako')

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Conclusiones sobre la tasa de repetición de pedido por total de pedidos
# El gráfico muestra la relación entre el número total de veces que se ha pedido un producto y su tasa promedio de repetición de pedido. Podemos observar que, en general, los productos que se han pedido más veces tienden a tener una tasa de repetición de pedido más alta. Esto sugiere que los productos populares no solo se venden con frecuencia, sino que también son los que los clientes vuelven a comprar con mayor regularidad

# %% [markdown]
# Conclusiones
# El análisis de la tasa de repetición de pedidos por producto es fundamental para entender qué artículos son recurrentes en las compras de los clientes. Al calcular el total_orders (cuántas veces se ha pedido un producto), total_reorders (cuántas veces se ha vuelto a pedir) y la reorder_ratio (proporción de repetición), podemos identificar los productos que generan mayor lealtad o necesidad. El gráfico de barras muestra visualmente que productos como 'Organic Whole Milk', 'Organic Banana', y 'Banana' tienen tasas de repetición muy altas, indicando que son artículos esenciales o muy preferidos por los clientes. Esta información es valiosa para la gestión de inventario, estrategias de marketing y para identificar los productos "gancho" que fidelizan a los usuarios.

# %% [markdown]
# ### [C4] Para cada cliente, ¿qué proporción de sus productos ya los había pedido?

# %% [markdown]
# 4. Para cada cliente, ¿qué proporción de los productos que pidió ya los había pedido? Calcula la tasa de repetición de pedido para cada usuario en lugar de para cada producto.

# %%
merged_orders_products = pd.merge(order_products_s, instacart_orders_s, on='order_id', how='left')

# Calcular el total de productos pedidos por cada usuario y el total de productos reordenados
user_reorder_stats = merged_orders_products.groupby('user_id').agg(
    total_products=('product_id', 'count'),
    reordered_products=('reordered', 'sum')
).reset_index()

# Calcular la proporción de productos reordenados para cada usuario
user_reorder_stats['reorder_proportion'] = user_reorder_stats['reordered_products'] / user_reorder_stats['total_products']

print("Estadísticas de repetición de pedido por usuario (primeras 5 filas):")
display(user_reorder_stats.head())
# Out:
# Estadísticas de repetición de pedido por usuario (primeras 5 filas):
#    user_id  total_products  reordered_products  reorder_proportion
# 0        2              26                   1            0.038462
# 1        4               2                   0            0.000000
# 2        5              12                   8            0.666667
# 3        6               4                   0            0.000000
# 4        7              14                  13            0.928571

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.histplot(user_reorder_stats['reorder_proportion'], bins=30, kde=True, color='skyblue')
plt.title('Distribución de la proporción de productos reordenados por usuario')
plt.xlabel('Proporción de Productos Reordenados')
plt.ylabel('Número de Usuarios')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
# sobre la proporción de productos reordenados por usuario
# El histograma muestra la distribución de la proporción de productos reordenados por cada cliente. Observamos que una gran cantidad de clientes tienen una proporción alta de reordenamiento, lo que indica que tienden a volver a comprar los mismos productos. Esto es consistente con el comportamiento de compra de comestibles, donde la gente a menudo recompra artículos básicos. También hay clientes con proporciones más bajas, lo que sugiere que algunos usuarios experimentan más con nuevos productos o tienen necesidades de compra más variadas.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# Bien hecho, muy bien con el cálculo por el lado de los usuarios.
#
# </div>

# %% [markdown]
# ### [C5] ¿Cuáles son los 20 principales artículos que las personas ponen primero en sus carritos?

# %% [markdown]
# 5. ¿Cuáles son los 20 principales artículos que la gente pone primero en sus carritos (muestra las IDs de los productos, sus nombres, y el número de veces en que fueron el primer artículo en añadirse al carrito)?

# %%
# Filtra los productos donde 'add_to_cart_order' es 1 (primer artículo en el carrito)
first_in_cart = order_products_s[order_products_s['add_to_cart_order'] == 1]

# Cuenta la frecuencia de cada producto que fue el primero en el carrito
first_in_cart_counts = first_in_cart['product_id'].value_counts().reset_index()
first_in_cart_counts.columns = ['product_id', 'times_first_in_cart']

# Fusiona con el DataFrame de productos para obtener los nombres de los productos
top_20_first_in_cart = pd.merge(first_in_cart_counts, products_s[['product_id', 'product_name']], on='product_id', how='left')

# Obtiene los 20 principales artículos
top_20_first_in_cart = top_20_first_in_cart.head(20)

print("Los 20 principales artículos que la gente pone primero en sus carritos:")
display(top_20_first_in_cart[['product_id', 'product_name', 'times_first_in_cart']])
# Out:
# Los 20 principales artículos que la gente pone primero en sus carritos:
#     product_id                 product_name  times_first_in_cart
# 0        24852                       Banana                15562
# 1        13176       Bag of Organic Bananas                11026
# 2        27845           Organic Whole Milk                 4363
# 3        21137         Organic Strawberries                 3946
# 4        47209         Organic Hass Avocado                 3390
# 5        21903         Organic Baby Spinach                 3336
# 6        47766              Organic Avocado                 3044
# 7        19660                 Spring Water                 2336
# 8        16797                 Strawberries                 2308
# 9        27966          Organic Raspberries                 2024
# 10       44632   Sparkling Water Grapefruit                 1914
# 11       49235          Organic Half & Half                 1797
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 7))
sns.barplot(x='product_name', y='times_first_in_cart', data=top_20_first_in_cart, palette='mako')
plt.title('Top 20 Artículos que se Ponen Primero en el Carrito')
plt.xlabel('Nombre del Producto')
plt.ylabel('Número de Veces como Primer Artículo')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\hilary\AppData\Local\Temp\ipykernel_27988\3587922041.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='product_name', y='times_first_in_cart', data=top_20_first_in_cart, palette='mako')

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# Buen trabajo. Al parecer los productos orgánicos representan el grueso de ventas en varios aspectos
#
# </div>

# %% [markdown]
# Escribe aquí tus conclusiones
# ### Conclusiones sobre los 20 principales artículos puestos primero en el carrito
#
# El análisis de los productos que los clientes añaden primero a sus carritos revela patrones interesantes sobre el comportamiento de compra. Los artículos que aparecen en este top 20 suelen ser productos básicos, de consumo frecuente o de alta prioridad en la lista de compras del cliente. Esto podría indicar que los clientes planifican su compra en torno a estos artículos o que son productos que necesitan con urgencia. Para las empresas, esta información es valiosa para la estrategia de posicionamiento de productos, promociones y diseño de la interfaz de usuario, sugiriendo cuáles productos deberían ser más visibles o fáciles de encontrar al inicio del proceso de compra.

# %% [markdown]
# ### Conclusión general del proyecto:
#
# Este proyecto se centró en el análisis de un conjunto de datos de Instacart, abarcando desde la descripción inicial de los datos hasta un análisis exploratorio detallado, pasando por un riguroso preprocesamiento. A continuación, se resumen los puntos clave:
#
# **1. Descripción de los Datos (Paso 1):**
#
# *   Se identificaron problemas iniciales de lectura de los archivos CSV debido a un separador incorrecto (`;`), lo que resultaba en DataFrames con una sola columna. Esto se corrigió especificando el parámetro `sep=';'` en `pd.read_csv()`.
# *   La inspección inicial con `head()`, `info()` y `describe()` reveló la estructura de los datos y la presencia de valores ausentes en columnas clave como `days_since_prior_order` (en `instacart_orders_s`), `product_name` (en `products_s`), y `product_id`, `add_to_cart_order`, `reordered` (en `order_products_s`).
#
# **2. Preprocesamiento de los Datos (Paso 2):**
#
# *   **Tipos de datos:** La columna `days_since_prior_order` fue convertida a `Int64` para manejar correctamente los valores nulos (primeros pedidos) sin perder su naturaleza entera.
# *   **Duplicados:**
#     *   Se eliminaron 15 filas duplicadas en `instacart_orders_s`.
#     *   No se encontraron duplicados exactos ni `product_id` duplicados en `products_s`, `departments_s` ni `aisles_s`.
#     *   En `products_s`, se identificaron 1258 nombres de productos ausentes y 1361 nombres de productos duplicados (tras estandarizar a mayúsculas), relacionados con `aisle_id` 100 y `department_id` 21, sugiriendo una categoría de productos genéricos/desconocidos. No se eliminaron ya que se consideraron productos distintos con nombres similares.
#     *   No se encontraron filas completamente duplicadas en `order_products_s`; las repeticiones de `product_id` o `reordered` individualmente se consideraron normales.
# *   **Valores Ausentes:**
#     *   Los 1258 valores ausentes en `product_name` de `products_s` se rellenaron con 'Unknown'.
#     *   Los 28817 valores ausentes en `days_since_prior_order` de `instacart_orders_s` se interpretaron como primeros pedidos y se mantuvieron como `NaN` (debido al tipo `Int64`).
#     *   Una única fila con `product_id` y `reordered` ausentes en `order_products_s` fue eliminada por ser un registro corrupto. Los 383 valores ausentes en `add_to_cart_order` se rellenaron con `999` y la columna se convirtió a tipo entero (`int`).
#
# **3. Análisis de los Datos (Paso 3):**
#
# *   **Verificación de rangos:** Se confirmó que las columnas `order_hour_of_day` (0-23) y `order_dow` (0-6) contenían valores razonables.
# *   **Distribución de pedidos:**
#     *   La mayoría de los pedidos se realizan entre las 10 a.m. y las 5 p.m., con menor actividad nocturna.
#     *   Los domingos y lunes son los días con mayor volumen de pedidos.
#     *   Muchos clientes esperan aproximadamente 7 días para realizar su siguiente pedido, aunque también hay un pico significativo en la espera de 30 días.
# *   **Comparativa Miércoles vs. Sábado:** El sábado muestra un mayor volumen de pedidos a lo largo del día en comparación con el miércoles, aunque ambos días comparten patrones similares de picos de actividad (mañana y tarde).
# *   **Pedidos por cliente:** La distribución muestra que la mayoría de los clientes realizan entre 3 y 5 pedidos, con una cola larga de clientes que hacen muchos más pedidos.
# *   **Productos Populares:** Los 20 productos más frecuentes son predominantemente artículos frescos y orgánicos, como plátanos, fresas, espinacas y aguacates, indicando la naturaleza de las compras en la plataforma.
# *   **Artículos por Pedido:** La distribución muestra que la mayoría de los pedidos contienen un número bajo de artículos, con un pico en 1-2 artículos y una disminución gradual a medida que aumenta la cantidad.
# *   **Tasa de Repetición de Pedidos:** Productos como la 'Organic Whole Milk' y el 'Banana' tienen tasas de repetición muy altas, lo que indica que son artículos esenciales o muy preferidos por los clientes. En general, los productos más populares también son los que se reordenan con mayor frecuencia.
# *   **Proporción de Reordenado por Usuario:** Se observa que una gran cantidad de usuarios tienen una alta proporción de productos reordenados, lo que sugiere lealtad a ciertos artículos.
# *   **Artículos Primero en el Carrito:** Los productos que se añaden primero al carrito son en su mayoría artículos básicos y de alta frecuencia de compra, como plátanos, leche y aguacates, lo que refleja su prioridad en la lista de compras de los clientes.
#
# En resumen, este análisis proporciona una visión integral del comportamiento de compra en Instacart, destacando patrones de tiempo, preferencias de productos y hábitos de reordenamiento, lo cual es fundamental para estrategias de inventario, marketing y mejora de la experiencia del usuario.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# Gran trabajo con las conclusiones. La inclusión de valores clave aporta solidez al análisis, y el resumen de los hallazgos es claro y preciso. ¡Demuestras un buen manejo del enfoque analítico!
#
# </div>
